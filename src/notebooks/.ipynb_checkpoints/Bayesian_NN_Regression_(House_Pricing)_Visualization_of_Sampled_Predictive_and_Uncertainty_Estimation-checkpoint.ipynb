# %% [markdown]
# This notebook is to visualize the sampled predictive destribution of classes from MNIST dataset and a look at how the authors estimate uncertainties in predictions.
#
# As usual, we clone the repository to get the PyTorch models

# %%
#!git clone https://github.com/pankajb64/bayescnn.git

# %%
#!git pull

# %% [markdown]
# The models are stored under `bayescnn/Bayesian_CNN/utils/`. Change the working directory so python can find the `utils`  modules.

# %%
#import os
#os.chdir('bayescnn/Bayesian_CNN')

# %% [markdown]
# Now we do all the relevant imports

# %%
#@title
from __future__ import print_function

import os
import sys
import time
import argparse
import datetime
import math
import pickle
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import torchvision
import torchvision.transforms as transforms

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
from torch.autograd import Variable

#import Bayesian_config as cf
from scipy.special import softmax
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize

# %%
#add the bayescnn to import path - https://stackoverflow.com/a/35273613/7154530
module_path = os.path.abspath(os.path.join('../bayesiancnn'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from BBBlayers import GaussianVariationalInference
from BBBlayers import BBBLinearFactorial

from BayesianModels.Bayesian3Conv3FC import BBB3Conv3FC
from BayesianModels.BayesianAlexNet import BBBAlexNet
from BayesianModels.BayesianLeNet import BBBLeNet

from preprocessing.houses_preprocessing import load_house_attributes, process_house_attributes
from BayesianModels.BBBFCHousePricing import BBBFCHousePricing

# %% [markdown]
# Configure the variables below to tweak the model and the dataset you want to choose, along with other things such as #epochs, learning rate, etc.

# %%
#@title
net_type = 'houses-bnn'
dataset = 'houses'
#net_type = 'alexnet'
#dataset = 'mnist'
outputs = 10
inputs = 1
regression = True
resume = False
start_epoch = 0
n_epochs = 200 #set to 10 for MNIST, 30 for cifar10, and 10 for house pricing
lr = 0.001
weight_decay = 0.1
num_samples = 10000
beta_type = "Blundell"
resize=32
optim_type = 'Adam'
best_acc = 0
best_loss = np.inf
# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 256
# percentage of training set to use as validation
valid_size = 0.2
#load every nth saved epoch (change to a smaller number for classification problems where num_epochs is less)
load_multiple = 1 #set to 25 (or 10) for house pricing, 1 for MNIST, 3 for cifar10
classes = []
torch.autograd.set_detect_anomaly(True)

# %% [markdown]
# This things like crawls on CPU, better use a GPU with CUDA support.

# %%
# Hyper Parameter settings
use_cuda = torch.cuda.is_available()
if use_cuda is True:
    torch.cuda.set_device(0)

# %% [markdown]
# Load the Training and Test Images for the dataset, resize and normalize them. Mean and Std Deviation provided by the authors for normalizing the images.

# %%
#@title
mean = {
    'cifar10': (0.4914, 0.4822, 0.4465),
    'cifar100': (0.5071, 0.4867, 0.4408),
    'mnist': (0.1307,),
    'houses': (0),
}

std = {
    'cifar10': (0.2023, 0.1994, 0.2010),
    'cifar100': (0.2675, 0.2565, 0.2761),
    'mnist': (0.3081,),
    'houses': (0),
}


transform_train = transforms.Compose([
    transforms.Resize((resize, resize)),
    transforms.ToTensor(),
    transforms.Normalize(mean[dataset.lower()], std[dataset.lower()]),
])  # meanstd transformation

transform_test = transforms.Compose([
    transforms.Resize((resize, resize)),
    transforms.ToTensor(),
    transforms.Normalize(mean[dataset.lower()], std[dataset.lower()]),
])

if (dataset == 'cifar10'):
    print("| Preparing CIFAR-10 dataset...")
    sys.stdout.write("| ")
    trainset = torchvision.datasets.CIFAR10(root='../../data/bayesiancnn', train=True, download=True, transform=transform_train)
    testset = torchvision.datasets.CIFAR10(root='../../data/bayesiancnn', train=False, download=False, transform=transform_test)
    outputs = 10
    inputs = 3
    regression = False
    classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

elif (dataset == 'cifar100'):
    print("| Preparing CIFAR-100 dataset...")
    sys.stdout.write("| ")
    trainset = torchvision.datasets.CIFAR100(root='../../data/bayesiancnn', train=True, download=True, transform=transform_train)
    testset = torchvision.datasets.CIFAR100(root='../../data/bayesiancnn', train=False, download=False, transform=transform_test)
    outputs = 100
    inputs = 3
    regression = False

elif (dataset == 'mnist'):
    print("| Preparing MNIST dataset...")
    sys.stdout.write("| ")
    trainset = torchvision.datasets.MNIST(root='../../data/bayesiancnn', train=True, download=True, transform=transform_train)
    testset = torchvision.datasets.MNIST(root='../../data/bayesiancnn', train=False, download=False, transform=transform_test)
    outputs = 10
    inputs = 1
    regression = False
    classes = range(10)
    
elif (dataset == 'houses'):
    print("| Preparing HOUSES dataset...")
    sys.stdout.write("| ")
    df = load_house_attributes('../../data/bayesiancnn/Houses-dataset/HousesInfo.txt')
    maxPrice = 2000000
    df = df[df['price'] < maxPrice]
    (train, test) = train_test_split(df, test_size=0.25, random_state=42)
    trainY = train["price"]/maxPrice
    testY = test["price"]/maxPrice
    (trainX, testX) = process_house_attributes(df, train, test)
    tensor_x_train = torch.stack([torch.Tensor(i) for i in trainX]) # transform to torch tensors
    tensor_y_train = torch.stack([torch.Tensor(i) for i in trainY.values.reshape(-1, 1)])
    trainset = torch.utils.data.TensorDataset(tensor_x_train,tensor_y_train) # create your datset
    tensor_x_test = torch.stack([torch.Tensor(i) for i in testX]) # transform to torch tensors
    tensor_y_test = torch.stack([torch.Tensor(i) for i in testY.values.reshape(-1, 1)])
    testset = torch.utils.data.TensorDataset(tensor_x_test,tensor_y_test) # create your datset
    outputs = 1
    inputs = trainX.shape[1]
    regression = True
    lr = 0.1
    classes = ('Regression') #dummy
    batch_size = 32

trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=4)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=4)
# Out:
# | Preparing HOUSES dataset...
# |

# %%
def mare_loss(input, target):
        loss = torch.mean(torch.abs(target - input)/torch.abs(target))
        #print(loss)
        return loss

# %% [markdown]
# Define the class labels. This is for CIFAR 10 and MNIST. (We defined a dummy class for regression.)

# %% [markdown]
# Load the Bayesian CNN Model.

# %%
if (net_type == 'lenet'):
    net = BBBLeNet(outputs,inputs)
elif (net_type == 'alexnet'):
    net = BBBAlexNet(outputs,inputs)
elif (net_type == '3conv3fc'):
    net = BBB3Conv3FC(outputs,inputs)
elif (net_type == 'houses-bnn'):
    net = BBBFCHousePricing(inputs, bias=True) #change bias=True to add bias to each unit
else:
    print('Error : Network should be either [LeNet / AlexNet /SqueezeNet/ 3Conv3FC/ BBBFCHousePricing')

if use_cuda:
    net.cuda()


loss, log = (torch.nn.CrossEntropyLoss(), False) if not regression else (torch.nn.MSELoss(), True)

vi = GaussianVariationalInference(loss, log=log)


logfile = os.path.join('diagnostics_Bayes{}_{}.txt'.format(net_type, dataset))

# %% [markdown]
# Define the functions for train and test.

# %%
def learning_rate(init, epoch):
    optim_factor = 0
    if(epoch > 160):
        optim_factor = 3
    elif(epoch > 120):
        optim_factor = 2
    elif(epoch > 60):
        optim_factor = 1

    return init*math.pow(0.2, optim_factor)

def get_hms(seconds):
    m, s = divmod(seconds, 60)
    h, m = divmod(m, 60)

    return h, m, s

# %%
#@title
def train(epoch):
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    m = math.ceil(len(trainset) / batch_size)
    optimizer = optim.Adam(net.parameters(), lr=learning_rate(lr, epoch), weight_decay=weight_decay)

    print('\n=> Training Epoch #%d, LR=%.4f' %(epoch, learning_rate(lr, epoch)))
    for batch_idx, (inputs_value, targets) in enumerate(trainloader):
        if net_type == 'houses-bnn':
          x = inputs_value.view(-1, inputs).repeat(num_samples, 1)
          y = targets.view(-1, outputs).repeat(num_samples, 1)
        else:  
          x = inputs_value.view(-1, inputs, resize, resize).repeat(num_samples, 1, 1, 1)
          y = targets.repeat(num_samples)
        if use_cuda:
            x, y = x.cuda(), y.cuda() # GPU settings

        if beta_type is "Blundell":
            beta = 2 ** (m - (batch_idx + 1)) / (2 ** m - 1)
        elif beta_type is "Soenderby":
            beta = min(epoch / (num_epochs // 4), 1)
        elif beta_type is "Standard":
            beta = 1 / m
        else:
            beta = 0
        # Forward Propagation
        x, y = Variable(x), Variable(y)
        outs, kl = net.probforward(x)
        #print(outs[0], y[0])
        #print(y)
        loss = vi(outs, y, kl, beta)  # Loss
        optimizer.zero_grad()
        loss.backward()  # Backward Propagation
        optimizer.step()  # Optimizer update

        train_loss += loss.data.item()
        loss = loss.data.item()
        if not regression:
          _, predicted = torch.max(outs.data, 1)
          total += targets.size(0)
          correct += predicted.eq(y.data).cpu().sum()
          sys.stdout.write('\r')
          sys.stdout.write('| Epoch [%3d/%3d] Iter[%3d/%3d]\t\tIter Loss: %.4f, Cumulative Loss: %.4f, Acc@1: %.3f%%' %(epoch, n_epochs-1, batch_idx+1,
                    (len(trainset)//batch_size)+1, loss, train_loss, (100*correct/total)/num_samples))
        else:
          sys.stdout.write('\r')
          sys.stdout.write('| Epoch [%3d/%3d] Iter[%3d/%3d]\t\tIter Loss: %.4f, Cumulative Loss: %.4f' %(epoch, n_epochs-1, batch_idx+1,
                    (len(trainset)//batch_size)+1, loss, train_loss))

        sys.stdout.flush()
    
    
    diagnostics_to_write = {'Epoch': epoch, 'Loss': train_loss}
    
    if not regression:
      acc =(100*correct/total)/num_samples
      diagnostics_to_write['Accuracy'] = acc                     
    
    with open(logfile, 'a') as lf:
        lf.write(str(diagnostics_to_write))
    
    if not regression:
      return train_loss, acc
    else:
      return train_loss

# %%
#@title 
def test(epoch, save_epoch=False):
    global best_acc, best_loss
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    conf=[]
    means = []
    vars = []
    confidence_means = []
    confidence_vars = []
    aleatorics = []
    epistemics = []
    m = math.ceil(len(testset) / batch_size)
    for batch_idx, (inputs_value, targets) in enumerate(testloader):
        if net_type == 'houses-bnn':
          x = inputs_value.view(-1, inputs).repeat(num_samples, 1)
          y = targets.view(-1, outputs).repeat(num_samples, 1)
        else:  
          x = inputs_value.view(-1, inputs, resize, resize).repeat(num_samples, 1, 1, 1)
          y = targets.repeat(num_samples)
        if use_cuda:
            x, y = x.cuda(), y.cuda()
        with torch.no_grad():
            x, y = Variable(x), Variable(y)
        outs, kl, mean, std = net.probforward(x, ret_mean_std=True)
        means.append(mean.mean().item())
        std_mean = std.mean()
        var_mean = std_mean ** 2
        vars.append(var_mean.item())
        #print(outs[0], y[0])
        if beta_type is "Blundell":
            beta = 2 ** (m - (batch_idx + 1)) / (2 ** m - 1)
        elif beta_type is "Soenderby":
            beta = min(epoch / (num_epochs // 4), 1)
        elif beta_type is "Standard":
            beta = 1 / m
        else:
            beta = 0

        loss = vi(outs, y, kl, beta)

        test_loss += loss.data.item()
        loss = loss.data.item()
        if not regression:
          _, predicted = torch.max(outs.data, 1)
          preds = F.softmax(outs, dim=1)
          total += targets.size(0)
          correct += predicted.eq(y.data).cpu().sum()
          results = torch.topk(preds.cpu().data, k=1, dim=1)
          p_hat = results.values.numpy().squeeze()
          confidence_mean = np.mean(p_hat, axis=0)
          confidence_var = np.var(p_hat, axis=0)
          epistemic = np.mean(p_hat ** 2, axis=0) - np.mean(p_hat, axis=0) ** 2
          aleatoric = np.mean(p_hat * (1 - p_hat), axis=0)
          #conf.append(results[0][0].item()) 
        else:
          preds = outs
          results = preds.detach().cpu().numpy() #torch.topk(preds.cpu().data, k=1, dim=0)
          mn = mean.detach().cpu().numpy()
          vn = std.detach().cpu().numpy() ** 2
          confidence_mean = np.mean(results, axis=0)
          confidence_var = np.var(results, axis=0)
          epistemic = np.mean(mn ** 2, axis=0) - np.mean(mn, axis=0) ** 2 #np.mean(p_hat ** 2, axis=0) - np.mean(p_hat, axis=0) ** 2
          aleatoric = np.mean(vn)
        confidence_means.append(confidence_mean)
        confidence_vars.append(confidence_var)
        epistemics.append(epistemic)
        aleatorics.append(aleatoric)
    
    

    # Save checkpoint when best model
    #print('\n{}\n{}\n{}'.format(conf, means, vars))
    #print(conf)
    #p_hat = np.array(conf)
    #means = np.array(means)
    #vars = np.array(vars)
    #print(np.mean(means ** 2, axis=0))
    #print(',')
    #print(np.mean(means, axis=0) ** 2)
    confidence_mean = np.sum(confidence_means) #np.mean(p_hat, axis=0)
    confidence_var = np.sum(confidence_vars) #np.var(p_hat, axis=0)
    epistemic = np.sum(epistemics) #np.mean(means ** 2, axis=0) - np.mean(means, axis=0) ** 2 #np.mean(p_hat ** 2, axis=0) - np.mean(p_hat, axis=0) ** 2
    aleatoric = np.sum(aleatorics) #np.mean(vars) #np.mean(p_hat * (1 - p_hat), axis=0)

    if not regression:
      acc =(100*correct/total)/num_samples
      print('\n| Validation Epoch #%d\t\t\tLoss: %.4f Acc@1: %.2f%%' %(epoch, test_loss, acc))
    else:
      print('\n| Validation Epoch #%d\t\t\tLoss: %.4f' %(epoch, test_loss))
    
    print('\n | Validation Epoch #%d\t\t\tConfidence Mean: %.2f Variance: %.4f Epistemic Uncertainty: %.4f Aleatoric Uncertainty: %.4f'%(epoch, confidence_mean, confidence_var, epistemic, aleatoric))
    test_diagnostics_to_write = {'Validation Epoch': epoch, 'Loss': test_loss}
    
    if not regression:
      test_diagnostics_to_write['Accuracy'] = acc
      
    with open(logfile, 'a') as lf:
        lf.write(str(test_diagnostics_to_write))

    state = {
        'net':net,
        'epoch':epoch,
        'loss': test_loss,
        }
    
    if not regression:
      state['acc'] = acc
    
    if save_epoch:
       if not os.path.isdir('checkpoint'):
            os.mkdir('checkpoint')
       
       save_point = './checkpoint-{}-{}-epoch-{}.pt'.format(net_type, dataset, epoch)
       torch.save(state, save_point)
       print('Saved Epoch {} as {}'.format(epoch, save_point))
      
    if (regression and test_loss < best_loss) or (not regression and acc > best_acc):
        if not regression:
          print('| Saving Best model...\t\t\tTop1 = %.2f%%' %(acc))
          best_acc = acc
        else:
          print('| Saving Best model...\t\t\tLoss = %.2f' %(test_loss))
          best_loss = test_loss
        
        if not os.path.isdir('checkpoint'):
            os.mkdir('checkpoint')
        save_point = './checkpoint/'+dataset+os.sep
        ckpt_name = f'model_{net_type}_{dataset}_bayesian.pt'
        if not os.path.isdir(save_point):
            os.mkdir(save_point)
        torch.save(state, save_point+ckpt_name)
    
    if not regression:
      return test_loss, acc
    else:
      return test_loss

# %% [markdown]
# We save approx every 3rd epoch to help visualize later.
#
# Ready, Set, Go!

# %%
#@title
elapsed_time = 0
saved_epochs = []

train_losses = []
train_accs = []

val_losses = []
val_accs = []

for epoch in range(start_epoch, start_epoch+n_epochs):
    start_time = time.time()

    if not regression:
      tloss, tacc = train(epoch)
      train_losses.append(tloss)
      train_accs.append(tacc)
      if (epoch%1 == 0):
        vloss, vacc = test(epoch, save_epoch = True )
        saved_epochs.append(epoch)
      else:
        vloss, vacc = test(epoch)
      val_losses.append(vloss)
      val_accs.append(vacc)
    else:
      tloss = train(epoch)
      train_losses.append(tloss)
      if (epoch%1 == 0):
        vloss = test(epoch, save_epoch = True )
        saved_epochs.append(epoch)
      else:
        vloss = test(epoch)
      val_losses.append(vloss)
    
    epoch_time = time.time() - start_time
    elapsed_time += epoch_time
    print('| Elapsed time : %d:%02d:%02d' %(get_hms(elapsed_time)))

if not regression:    
  print('\n Test results : Acc@1 = %.2f%%' %(best_acc))
else:
  print('\n Test results : Loss = %.2f' %(best_loss))
# Out:
# => Training Epoch #0, LR=0.1000
# | Epoch [  0/199] Iter[  9/  9]		Iter Loss: 5.4657, Cumulative Loss: 1525.3274
# | Validation Epoch #0			Loss: 945.7184
#
#  | Validation Epoch #0			Confidence Mean: 1.29 Variance: 54.9542 Epistemic Uncertainty: 18.1274 Aleatoric Uncertainty: 36.9156
# Saved Epoch 0 as ./checkpoint-houses-bnn-houses-epoch-0.pt
# | Saving Best model...			Loss = 945.72
# | Elapsed time : 0:00:01
#
# => Training Epoch #1, LR=0.1000
# | Epoch [  1/199] Iter[  9/  9]		Iter Loss: 1.5351, Cumulative Loss: 841.8365
# | Validation Epoch #1			Loss: 438.9794
#
#  | Validation Epoch #1			Confidence Mean: -1.09 Variance: 2.9162 Epistemic Uncertainty: 1.1773 Aleatoric Uncertainty: 1.7288
# Saved Epoch 1 as ./checkpoint-houses-bnn-houses-epoch-1.pt
# | Saving Best model...			Loss = 438.98
# | Elapsed time : 0:00:02
#
# => Training Epoch #2, LR=0.1000
# | Epoch [  2/199] Iter[  9/  9]		Iter Loss: -1.1833, Cumulative Loss: 397.7786
# | Validation Epoch #2			Loss: 199.9284
#
#  | Validation Epoch #2			Confidence Mean: 0.74 Variance: 0.4191 Epistemic Uncertainty: 0.0548 Aleatoric Uncertainty: 0.3645
# Saved Epoch 2 as ./checkpoint-houses-bnn-houses-epoch-2.pt
# | Saving Best model...			Loss = 199.93
# | Elapsed time : 0:00:03
#
# => Training Epoch #3, LR=0.1000
# | Epoch [  3/199] Iter[  9/  9]		Iter Loss: -1.9221, Cumulative Loss: 171.5732
# | Validation Epoch #3			Loss: 96.8350
#
#  | Validation Epoch #3			Confidence Mean: 0.85 Variance: 0.1218 Epistemic Uncertainty: 0.0032 Aleatoric Uncertainty: 0.1185
# Saved Epoch 3 as ./checkpoint-houses-bnn-houses-epoch-3.pt
# | Saving Best model...			Loss = 96.84
# | Elapsed time : 0:00:04
#
# => Training Epoch #4, LR=0.1000
# | Epoch [  4/199] Iter[  9/  9]		Iter Loss: -2.6672, Cumulative Loss: 50.3055
# | Validation Epoch #4			Loss: 81.2880
#
#  | Validation Epoch #4			Confidence Mean: 0.74 Variance: 0.0582 Epistemic Uncertainty: 0.0007 Aleatoric Uncertainty: 0.0574
# Saved Epoch 4 as ./checkpoint-houses-bnn-houses-epoch-4.pt
# | Saving Best model...			Loss = 81.29
# | Elapsed time : 0:00:05
#
# => Training Epoch #5, LR=0.1000
# | Epoch [  5/199] Iter[  9/  9]		Iter Loss: -2.8955, Cumulative Loss: 61.4760
# | Validation Epoch #5			Loss: 69.7154
#
#  | Validation Epoch #5			Confidence Mean: 0.60 Variance: 0.0774 Epistemic Uncertainty: 0.0012 Aleatoric Uncertainty: 0.0761
# Saved Epoch 5 as ./checkpoint-houses-bnn-houses-epoch-5.pt
# | Saving Best model...			Loss = 69.72
# | Elapsed time : 0:00:06
#
# => Training Epoch #6, LR=0.1000
# | Epoch [  6/199] Iter[  9/  9]		Iter Loss: -2.8329, Cumulative Loss: 40.6512
# | Validation Epoch #6			Loss: 43.2709
#
#  | Validation Epoch #6			Confidence Mean: 0.74 Variance: 0.0731 Epistemic Uncertainty: 0.0021 Aleatoric Uncertainty: 0.0711
# Saved Epoch 6 as ./checkpoint-houses-bnn-houses-epoch-6.pt
# | Saving Best model...			Loss = 43.27
# | Elapsed time : 0:00:07
#
# => Training Epoch #7, LR=0.1000
# | Epoch [  7/199] Iter[  9/  9]		Iter Loss: -3.2546, Cumulative Loss: 43.4075
# | Validation Epoch #7			Loss: 73.8265
#
#  | Validation Epoch #7			Confidence Mean: 0.83 Variance: 0.0687 Epistemic Uncertainty: 0.0013 Aleatoric Uncertainty: 0.0672
# Saved Epoch 7 as ./checkpoint-houses-bnn-houses-epoch-7.pt
# | Elapsed time : 0:00:08
#
# => Training Epoch #8, LR=0.1000
# | Epoch [  8/199] Iter[  9/  9]		Iter Loss: -2.6234, Cumulative Loss: 40.8160
# | Validation Epoch #8			Loss: 90.7562
#
#  | Validation Epoch #8			Confidence Mean: 0.68 Variance: 0.0704 Epistemic Uncertainty: 0.0012 Aleatoric Uncertainty: 0.0690
# Saved Epoch 8 as ./checkpoint-houses-bnn-houses-epoch-8.pt
# | Elapsed time : 0:00:09
#
# => Training Epoch #9, LR=0.1000
# | Epoch [  9/199] Iter[  9/  9]		Iter Loss: -3.0967, Cumulative Loss: 62.5231
# | Validation Epoch #9			Loss: 70.2645
#
#  | Validation Epoch #9			Confidence Mean: 0.60 Variance: 0.0778 Epistemic Uncertainty: 0.0013 Aleatoric Uncertainty: 0.0767
# Saved Epoch 9 as ./checkpoint-houses-bnn-houses-epoch-9.pt
# | Elapsed time : 0:00:10
#
# => Training Epoch #10, LR=0.1000
# | Epoch [ 10/199] Iter[  9/  9]		Iter Loss: -2.8170, Cumulative Loss: 58.5919
# | Validation Epoch #10			Loss: 120.1588
#
#  | Validation Epoch #10			Confidence Mean: 0.66 Variance: 0.0725 Epistemic Uncertainty: 0.0008 Aleatoric Uncertainty: 0.0716
# Saved Epoch 10 as ./checkpoint-houses-bnn-houses-epoch-10.pt
# | Elapsed time : 0:00:11
#
# => Training Epoch #11, LR=0.1000
# | Epoch [ 11/199] Iter[  9/  9]		Iter Loss: -2.9167, Cumulative Loss: 90.5591
# | Validation Epoch #11			Loss: 43.0229
#
#  | Validation Epoch #11			Confidence Mean: 0.64 Variance: 0.0826 Epistemic Uncertainty: 0.0025 Aleatoric Uncertainty: 0.0799
# Saved Epoch 11 as ./checkpoint-houses-bnn-houses-epoch-11.pt
# | Saving Best model...			Loss = 43.02
# | Elapsed time : 0:00:12
#
# => Training Epoch #12, LR=0.1000
# | Epoch [ 12/199] Iter[  9/  9]		Iter Loss: -3.0543, Cumulative Loss: 70.6716
# | Validation Epoch #12			Loss: 65.7713
#
#  | Validation Epoch #12			Confidence Mean: 0.87 Variance: 0.0745 Epistemic Uncertainty: 0.0005 Aleatoric Uncertainty: 0.0740
# Saved Epoch 12 as ./checkpoint-houses-bnn-houses-epoch-12.pt
# | Elapsed time : 0:00:13
#
# => Training Epoch #13, LR=0.1000
# | Epoch [ 13/199] Iter[  9/  9]		Iter Loss: -2.8929, Cumulative Loss: 46.7098
# | Validation Epoch #13			Loss: 60.9373
#
#  | Validation Epoch #13			Confidence Mean: 0.59 Variance: 0.0740 Epistemic Uncertainty: 0.0018 Aleatoric Uncertainty: 0.0721
# Saved Epoch 13 as ./checkpoint-houses-bnn-houses-epoch-13.pt
# | Elapsed time : 0:00:14
#
# => Training Epoch #14, LR=0.1000
# | Epoch [ 14/199] Iter[  9/  9]		Iter Loss: -2.9817, Cumulative Loss: 59.3107
# | Validation Epoch #14			Loss: 91.0449
#
#  | Validation Epoch #14			Confidence Mean: 0.98 Variance: 0.0706 Epistemic Uncertainty: 0.0006 Aleatoric Uncertainty: 0.0700
# Saved Epoch 14 as ./checkpoint-houses-bnn-houses-epoch-14.pt
# | Elapsed time : 0:00:15
#
# => Training Epoch #15, LR=0.1000
# | Epoch [ 15/199] Iter[  9/  9]		Iter Loss: -2.7511, Cumulative Loss: 55.3879
# | Validation Epoch #15			Loss: 104.0438
#
#  | Validation Epoch #15			Confidence Mean: 0.88 Variance: 0.0727 Epistemic Uncertainty: 0.0017 Aleatoric Uncertainty: 0.0710
# Saved Epoch 15 as ./checkpoint-houses-bnn-houses-epoch-15.pt
# | Elapsed time : 0:00:16
#
# => Training Epoch #16, LR=0.1000
# | Epoch [ 16/199] Iter[  9/  9]		Iter Loss: -3.1988, Cumulative Loss: 81.9352
# | Validation Epoch #16			Loss: 127.9968
#
#  | Validation Epoch #16			Confidence Mean: 0.88 Variance: 0.0732 Epistemic Uncertainty: 0.0014 Aleatoric Uncertainty: 0.0718
# Saved Epoch 16 as ./checkpoint-houses-bnn-houses-epoch-16.pt
# | Elapsed time : 0:00:17
#
# => Training Epoch #17, LR=0.1000
# | Epoch [ 17/199] Iter[  9/  9]		Iter Loss: -2.7287, Cumulative Loss: 60.2010
# | Validation Epoch #17			Loss: 78.1934
#
#  | Validation Epoch #17			Confidence Mean: 0.58 Variance: 0.0732 Epistemic Uncertainty: 0.0002 Aleatoric Uncertainty: 0.0729
# Saved Epoch 17 as ./checkpoint-houses-bnn-houses-epoch-17.pt
# | Elapsed time : 0:00:18
#
# => Training Epoch #18, LR=0.1000
# | Epoch [ 18/199] Iter[  9/  9]		Iter Loss: -2.8709, Cumulative Loss: 49.5711
# | Validation Epoch #18			Loss: 117.5521
#
#  | Validation Epoch #18			Confidence Mean: 0.78 Variance: 0.0611 Epistemic Uncertainty: 0.0003 Aleatoric Uncertainty: 0.0607
# Saved Epoch 18 as ./checkpoint-houses-bnn-houses-epoch-18.pt
# | Elapsed time : 0:00:19
#
# => Training Epoch #19, LR=0.1000
# | Epoch [ 19/199] Iter[  9/  9]		Iter Loss: -2.9996, Cumulative Loss: 58.0048
# | Validation Epoch #19			Loss: 62.4951
#
#  | Validation Epoch #19			Confidence Mean: 0.53 Variance: 0.0692 Epistemic Uncertainty: 0.0011 Aleatoric Uncertainty: 0.0681
# Saved Epoch 19 as ./checkpoint-houses-bnn-houses-epoch-19.pt
# | Elapsed time : 0:00:20
#
# => Training Epoch #20, LR=0.1000
# | Epoch [ 20/199] Iter[  9/  9]		Iter Loss: -2.8776, Cumulative Loss: 71.3003
# | Validation Epoch #20			Loss: 77.0732
#
#  | Validation Epoch #20			Confidence Mean: 0.81 Variance: 0.0741 Epistemic Uncertainty: 0.0010 Aleatoric Uncertainty: 0.0730
# Saved Epoch 20 as ./checkpoint-houses-bnn-houses-epoch-20.pt
# | Elapsed time : 0:00:21
#
# => Training Epoch #21, LR=0.1000
# | Epoch [ 21/199] Iter[  9/  9]		Iter Loss: -2.8627, Cumulative Loss: 44.8768
# | Validation Epoch #21			Loss: 141.6556
#
#  | Validation Epoch #21			Confidence Mean: 0.62 Variance: 0.0855 Epistemic Uncertainty: 0.0045 Aleatoric Uncertainty: 0.0810
# Saved Epoch 21 as ./checkpoint-houses-bnn-houses-epoch-21.pt
# | Elapsed time : 0:00:22
#
# => Training Epoch #22, LR=0.1000
# | Epoch [ 22/199] Iter[  9/  9]		Iter Loss: -2.3649, Cumulative Loss: 49.0406
# | Validation Epoch #22			Loss: 76.0525
#
#  | Validation Epoch #22			Confidence Mean: 0.69 Variance: 0.0795 Epistemic Uncertainty: 0.0019 Aleatoric Uncertainty: 0.0775
# Saved Epoch 22 as ./checkpoint-houses-bnn-houses-epoch-22.pt
# | Elapsed time : 0:00:23
#
# => Training Epoch #23, LR=0.1000
# | Epoch [ 23/199] Iter[  9/  9]		Iter Loss: -2.9732, Cumulative Loss: 69.6637
# | Validation Epoch #23			Loss: 95.6315
#
#  | Validation Epoch #23			Confidence Mean: 0.83 Variance: 0.0755 Epistemic Uncertainty: 0.0017 Aleatoric Uncertainty: 0.0739
# Saved Epoch 23 as ./checkpoint-houses-bnn-houses-epoch-23.pt
# | Elapsed time : 0:00:24
#
# => Training Epoch #24, LR=0.1000
# | Epoch [ 24/199] Iter[  9/  9]		Iter Loss: -3.0542, Cumulative Loss: 58.6352
# | Validation Epoch #24			Loss: 92.3529
#
#  | Validation Epoch #24			Confidence Mean: 0.66 Variance: 0.0688 Epistemic Uncertainty: 0.0019 Aleatoric Uncertainty: 0.0668
# Saved Epoch 24 as ./checkpoint-houses-bnn-houses-epoch-24.pt
# | Elapsed time : 0:00:25
#
# => Training Epoch #25, LR=0.1000
# | Epoch [ 25/199] Iter[  9/  9]		Iter Loss: -2.8187, Cumulative Loss: 66.3799
# | Validation Epoch #25			Loss: 102.3987
#
#  | Validation Epoch #25			Confidence Mean: 0.90 Variance: 0.0763 Epistemic Uncertainty: 0.0021 Aleatoric Uncertainty: 0.0739
# Saved Epoch 25 as ./checkpoint-houses-bnn-houses-epoch-25.pt
# | Elapsed time : 0:00:26
#
# => Training Epoch #26, LR=0.1000
# | Epoch [ 26/199] Iter[  9/  9]		Iter Loss: -2.7127, Cumulative Loss: 72.0977
# | Validation Epoch #26			Loss: 123.2506
#
#  | Validation Epoch #26			Confidence Mean: 0.96 Variance: 0.0774 Epistemic Uncertainty: 0.0008 Aleatoric Uncertainty: 0.0764
# Saved Epoch 26 as ./checkpoint-houses-bnn-houses-epoch-26.pt
# | Elapsed time : 0:00:27
#
# => Training Epoch #27, LR=0.1000
# | Epoch [ 27/199] Iter[  9/  9]		Iter Loss: -2.5868, Cumulative Loss: 94.5380
# | Validation Epoch #27			Loss: 75.2341
#
#  | Validation Epoch #27			Confidence Mean: 1.02 Variance: 0.0826 Epistemic Uncertainty: 0.0009 Aleatoric Uncertainty: 0.0818
# Saved Epoch 27 as ./checkpoint-houses-bnn-houses-epoch-27.pt
# | Elapsed time : 0:00:28
#
# => Training Epoch #28, LR=0.1000
# | Epoch [ 28/199] Iter[  9/  9]		Iter Loss: -2.3474, Cumulative Loss: 38.2569
# | Validation Epoch #28			Loss: 62.1093
#
#  | Validation Epoch #28			Confidence Mean: 0.61 Variance: 0.0716 Epistemic Uncertainty: 0.0026 Aleatoric Uncertainty: 0.0689
# Saved Epoch 28 as ./checkpoint-houses-bnn-houses-epoch-28.pt
# | Elapsed time : 0:00:29
#
# => Training Epoch #29, LR=0.1000
# | Epoch [ 29/199] Iter[  9/  9]		Iter Loss: -3.0042, Cumulative Loss: 61.2071
# | Validation Epoch #29			Loss: 93.7416
#
#  | Validation Epoch #29			Confidence Mean: 0.63 Variance: 0.0701 Epistemic Uncertainty: 0.0012 Aleatoric Uncertainty: 0.0690
# Saved Epoch 29 as ./checkpoint-houses-bnn-houses-epoch-29.pt
# | Elapsed time : 0:00:30
#
# => Training Epoch #30, LR=0.1000
# | Epoch [ 30/199] Iter[  9/  9]		Iter Loss: -2.6091, Cumulative Loss: 73.8512
# | Validation Epoch #30			Loss: 119.4904
#
#  | Validation Epoch #30			Confidence Mean: 1.01 Variance: 0.0709 Epistemic Uncertainty: 0.0014 Aleatoric Uncertainty: 0.0695
# Saved Epoch 30 as ./checkpoint-houses-bnn-houses-epoch-30.pt
# | Elapsed time : 0:00:31
#
# => Training Epoch #31, LR=0.1000
# | Epoch [ 31/199] Iter[  9/  9]		Iter Loss: -2.3504, Cumulative Loss: 31.9456
# | Validation Epoch #31			Loss: 134.7744
#
#  | Validation Epoch #31			Confidence Mean: 0.52 Variance: 0.0724 Epistemic Uncertainty: 0.0016 Aleatoric Uncertainty: 0.0705
# Saved Epoch 31 as ./checkpoint-houses-bnn-houses-epoch-31.pt
# | Elapsed time : 0:00:32
#
# => Training Epoch #32, LR=0.1000
# | Epoch [ 32/199] Iter[  9/  9]		Iter Loss: -2.8553, Cumulative Loss: 86.7156
# | Validation Epoch #32			Loss: 107.7038
#
#  | Validation Epoch #32			Confidence Mean: 0.74 Variance: 0.0676 Epistemic Uncertainty: 0.0003 Aleatoric Uncertainty: 0.0671
# Saved Epoch 32 as ./checkpoint-houses-bnn-houses-epoch-32.pt
# | Elapsed time : 0:00:33
#
# => Training Epoch #33, LR=0.1000
# | Epoch [ 33/199] Iter[  9/  9]		Iter Loss: -2.7396, Cumulative Loss: 75.9820
# | Validation Epoch #33			Loss: 78.5129
#
#  | Validation Epoch #33			Confidence Mean: 0.82 Variance: 0.0745 Epistemic Uncertainty: 0.0004 Aleatoric Uncertainty: 0.0740
# Saved Epoch 33 as ./checkpoint-houses-bnn-houses-epoch-33.pt
# | Elapsed time : 0:00:34
#
# => Training Epoch #34, LR=0.1000
# | Epoch [ 34/199] Iter[  9/  9]		Iter Loss: -2.8219, Cumulative Loss: 31.3623
# | Validation Epoch #34			Loss: 35.6743
#
#  | Validation Epoch #34			Confidence Mean: 0.73 Variance: 0.0723 Epistemic Uncertainty: 0.0013 Aleatoric Uncertainty: 0.0709
# Saved Epoch 34 as ./checkpoint-houses-bnn-houses-epoch-34.pt
# | Saving Best model...			Loss = 35.67
# | Elapsed time : 0:00:35
#
# => Training Epoch #35, LR=0.1000
# | Epoch [ 35/199] Iter[  9/  9]		Iter Loss: -2.5561, Cumulative Loss: 42.5959
# | Validation Epoch #35			Loss: 114.5369
#
#  | Validation Epoch #35			Confidence Mean: 0.71 Variance: 0.0751 Epistemic Uncertainty: 0.0022 Aleatoric Uncertainty: 0.0729
# Saved Epoch 35 as ./checkpoint-houses-bnn-houses-epoch-35.pt
# | Elapsed time : 0:00:36
#
# => Training Epoch #36, LR=0.1000
# | Epoch [ 36/199] Iter[  9/  9]		Iter Loss: -2.4977, Cumulative Loss: 54.7454
# | Validation Epoch #36			Loss: 58.4132
#
#  | Validation Epoch #36			Confidence Mean: 0.69 Variance: 0.0858 Epistemic Uncertainty: 0.0029 Aleatoric Uncertainty: 0.0830
# Saved Epoch 36 as ./checkpoint-houses-bnn-houses-epoch-36.pt
# | Elapsed time : 0:00:37
#
# => Training Epoch #37, LR=0.1000
# | Epoch [ 37/199] Iter[  9/  9]		Iter Loss: -2.8800, Cumulative Loss: 34.3479
# | Validation Epoch #37			Loss: 93.3501
#
#  | Validation Epoch #37			Confidence Mean: 0.65 Variance: 0.0681 Epistemic Uncertainty: 0.0022 Aleatoric Uncertainty: 0.0660
# Saved Epoch 37 as ./checkpoint-houses-bnn-houses-epoch-37.pt
# | Elapsed time : 0:00:38
#
# => Training Epoch #38, LR=0.1000
# | Epoch [ 38/199] Iter[  9/  9]		Iter Loss: -2.3422, Cumulative Loss: 81.8346
# | Validation Epoch #38			Loss: 62.1671
#
#  | Validation Epoch #38			Confidence Mean: 0.88 Variance: 0.0787 Epistemic Uncertainty: 0.0028 Aleatoric Uncertainty: 0.0761
# Saved Epoch 38 as ./checkpoint-houses-bnn-houses-epoch-38.pt
# | Elapsed time : 0:00:39
#
# => Training Epoch #39, LR=0.1000
# | Epoch [ 39/199] Iter[  9/  9]		Iter Loss: -3.2574, Cumulative Loss: 74.6159
# | Validation Epoch #39			Loss: 80.2225
#
#  | Validation Epoch #39			Confidence Mean: 0.57 Variance: 0.0628 Epistemic Uncertainty: 0.0006 Aleatoric Uncertainty: 0.0621
# Saved Epoch 39 as ./checkpoint-houses-bnn-houses-epoch-39.pt
# | Elapsed time : 0:00:40
#
# => Training Epoch #40, LR=0.1000
# | Epoch [ 40/199] Iter[  9/  9]		Iter Loss: -2.2862, Cumulative Loss: 69.7650
# | Validation Epoch #40			Loss: 74.4571
#
#  | Validation Epoch #40			Confidence Mean: 0.85 Variance: 0.0806 Epistemic Uncertainty: 0.0009 Aleatoric Uncertainty: 0.0795
# Saved Epoch 40 as ./checkpoint-houses-bnn-houses-epoch-40.pt
# | Elapsed time : 0:00:41
#
# => Training Epoch #41, LR=0.1000
# | Epoch [ 41/199] Iter[  9/  9]		Iter Loss: -3.3526, Cumulative Loss: 39.8390
# | Validation Epoch #41			Loss: 65.7204
#
#  | Validation Epoch #41			Confidence Mean: 0.46 Variance: 0.0705 Epistemic Uncertainty: 0.0026 Aleatoric Uncertainty: 0.0677
# Saved Epoch 41 as ./checkpoint-houses-bnn-houses-epoch-41.pt
# | Elapsed time : 0:00:42
#
# => Training Epoch #42, LR=0.1000
# | Epoch [ 42/199] Iter[  9/  9]		Iter Loss: -2.7456, Cumulative Loss: 30.8841
# | Validation Epoch #42			Loss: 60.4638
#
#  | Validation Epoch #42			Confidence Mean: 0.65 Variance: 0.0758 Epistemic Uncertainty: 0.0008 Aleatoric Uncertainty: 0.0750
# Saved Epoch 42 as ./checkpoint-houses-bnn-houses-epoch-42.pt
# | Elapsed time : 0:00:43
#
# => Training Epoch #43, LR=0.1000
# | Epoch [ 43/199] Iter[  9/  9]		Iter Loss: -2.8865, Cumulative Loss: 64.8990
# | Validation Epoch #43			Loss: 38.0005
#
#  | Validation Epoch #43			Confidence Mean: 0.83 Variance: 0.0638 Epistemic Uncertainty: 0.0008 Aleatoric Uncertainty: 0.0632
# Saved Epoch 43 as ./checkpoint-houses-bnn-houses-epoch-43.pt
# | Elapsed time : 0:00:44
#
# => Training Epoch #44, LR=0.1000
# | Epoch [ 44/199] Iter[  9/  9]		Iter Loss: -2.6419, Cumulative Loss: 49.6378
# | Validation Epoch #44			Loss: 75.3755
#
#  | Validation Epoch #44			Confidence Mean: 0.83 Variance: 0.0751 Epistemic Uncertainty: 0.0015 Aleatoric Uncertainty: 0.0735
# Saved Epoch 44 as ./checkpoint-houses-bnn-houses-epoch-44.pt
# | Elapsed time : 0:00:46
#
# => Training Epoch #45, LR=0.1000
# | Epoch [ 45/199] Iter[  9/  9]		Iter Loss: -2.7493, Cumulative Loss: 78.2272
# | Validation Epoch #45			Loss: 77.4325
#
#  | Validation Epoch #45			Confidence Mean: 0.78 Variance: 0.0603 Epistemic Uncertainty: 0.0003 Aleatoric Uncertainty: 0.0600
# Saved Epoch 45 as ./checkpoint-houses-bnn-houses-epoch-45.pt
# | Elapsed time : 0:00:47
#
# => Training Epoch #46, LR=0.1000
# | Epoch [ 46/199] Iter[  9/  9]		Iter Loss: -2.5704, Cumulative Loss: 68.3171
# | Validation Epoch #46			Loss: 76.3920
#
#  | Validation Epoch #46			Confidence Mean: 0.58 Variance: 0.0831 Epistemic Uncertainty: 0.0018 Aleatoric Uncertainty: 0.0812
# Saved Epoch 46 as ./checkpoint-houses-bnn-houses-epoch-46.pt
# | Elapsed time : 0:00:48
#
# => Training Epoch #47, LR=0.1000
# | Epoch [ 47/199] Iter[  9/  9]		Iter Loss: -2.6656, Cumulative Loss: 60.4607
# | Validation Epoch #47			Loss: 82.8982
#
#  | Validation Epoch #47			Confidence Mean: 0.56 Variance: 0.0663 Epistemic Uncertainty: 0.0008 Aleatoric Uncertainty: 0.0654
# Saved Epoch 47 as ./checkpoint-houses-bnn-houses-epoch-47.pt
# | Elapsed time : 0:00:49
#
# => Training Epoch #48, LR=0.1000
# | Epoch [ 48/199] Iter[  9/  9]		Iter Loss: -2.0947, Cumulative Loss: 73.1811
# | Validation Epoch #48			Loss: 89.9704
#
#  | Validation Epoch #48			Confidence Mean: 0.77 Variance: 0.0847 Epistemic Uncertainty: 0.0024 Aleatoric Uncertainty: 0.0821
# Saved Epoch 48 as ./checkpoint-houses-bnn-houses-epoch-48.pt
# | Elapsed time : 0:00:50
#
# => Training Epoch #49, LR=0.1000
# | Epoch [ 49/199] Iter[  9/  9]		Iter Loss: -3.1210, Cumulative Loss: 79.3947
# | Validation Epoch #49			Loss: 78.6191
#
#  | Validation Epoch #49			Confidence Mean: 0.72 Variance: 0.0613 Epistemic Uncertainty: 0.0011 Aleatoric Uncertainty: 0.0602
# Saved Epoch 49 as ./checkpoint-houses-bnn-houses-epoch-49.pt
# | Elapsed time : 0:00:51
#
# => Training Epoch #50, LR=0.1000
# | Epoch [ 50/199] Iter[  9/  9]		Iter Loss: -2.7794, Cumulative Loss: 63.1654
# | Validation Epoch #50			Loss: 49.2987
#
#  | Validation Epoch #50			Confidence Mean: 0.90 Variance: 0.0737 Epistemic Uncertainty: 0.0010 Aleatoric Uncertainty: 0.0728
# Saved Epoch 50 as ./checkpoint-houses-bnn-houses-epoch-50.pt
# | Elapsed time : 0:00:52
#
# => Training Epoch #51, LR=0.1000
# | Epoch [ 51/199] Iter[  9/  9]		Iter Loss: -2.9804, Cumulative Loss: 40.2607
# | Validation Epoch #51			Loss: 81.2206
#
#  | Validation Epoch #51			Confidence Mean: 0.68 Variance: 0.0820 Epistemic Uncertainty: 0.0015 Aleatoric Uncertainty: 0.0808
# Saved Epoch 51 as ./checkpoint-houses-bnn-houses-epoch-51.pt
# | Elapsed time : 0:00:53
#
# => Training Epoch #52, LR=0.1000
# | Epoch [ 52/199] Iter[  9/  9]		Iter Loss: -3.0558, Cumulative Loss: 40.9911
# | Validation Epoch #52			Loss: 80.0313
#
#  | Validation Epoch #52			Confidence Mean: 0.53 Variance: 0.0691 Epistemic Uncertainty: 0.0005 Aleatoric Uncertainty: 0.0685
# Saved Epoch 52 as ./checkpoint-houses-bnn-houses-epoch-52.pt
# | Elapsed time : 0:00:54
#
# => Training Epoch #53, LR=0.1000
# | Epoch [ 53/199] Iter[  9/  9]		Iter Loss: -2.8497, Cumulative Loss: 80.1879
# | Validation Epoch #53			Loss: 78.8846
#
#  | Validation Epoch #53			Confidence Mean: 0.47 Variance: 0.0816 Epistemic Uncertainty: 0.0018 Aleatoric Uncertainty: 0.0798
# Saved Epoch 53 as ./checkpoint-houses-bnn-houses-epoch-53.pt
# | Elapsed time : 0:00:55
#
# => Training Epoch #54, LR=0.1000
# | Epoch [ 54/199] Iter[  9/  9]		Iter Loss: -2.1728, Cumulative Loss: 67.3429
# | Validation Epoch #54			Loss: 57.4376
#
#  | Validation Epoch #54			Confidence Mean: 0.59 Variance: 0.0802 Epistemic Uncertainty: 0.0018 Aleatoric Uncertainty: 0.0785
# Saved Epoch 54 as ./checkpoint-houses-bnn-houses-epoch-54.pt
# | Elapsed time : 0:00:56
#
# => Training Epoch #55, LR=0.1000
# | Epoch [ 55/199] Iter[  9/  9]		Iter Loss: -3.0444, Cumulative Loss: 47.9848
# | Validation Epoch #55			Loss: 79.7023
#
#  | Validation Epoch #55			Confidence Mean: 0.81 Variance: 0.0690 Epistemic Uncertainty: 0.0015 Aleatoric Uncertainty: 0.0675
# Saved Epoch 55 as ./checkpoint-houses-bnn-houses-epoch-55.pt
# | Elapsed time : 0:00:57
#
# => Training Epoch #56, LR=0.1000
# | Epoch [ 56/199] Iter[  9/  9]		Iter Loss: -3.0381, Cumulative Loss: 88.5568
# | Validation Epoch #56			Loss: 89.0476
#
#  | Validation Epoch #56			Confidence Mean: 0.79 Variance: 0.0741 Epistemic Uncertainty: 0.0022 Aleatoric Uncertainty: 0.0718
# Saved Epoch 56 as ./checkpoint-houses-bnn-houses-epoch-56.pt
# | Elapsed time : 0:00:58
#
# => Training Epoch #57, LR=0.1000
# | Epoch [ 57/199] Iter[  9/  9]		Iter Loss: -2.9265, Cumulative Loss: 42.5351
# | Validation Epoch #57			Loss: 107.4674
#
#  | Validation Epoch #57			Confidence Mean: 0.86 Variance: 0.0604 Epistemic Uncertainty: 0.0004 Aleatoric Uncertainty: 0.0601
# Saved Epoch 57 as ./checkpoint-houses-bnn-houses-epoch-57.pt
# | Elapsed time : 0:00:59
#
# => Training Epoch #58, LR=0.1000
# | Epoch [ 58/199] Iter[  9/  9]		Iter Loss: -2.9735, Cumulative Loss: 71.0528
# | Validation Epoch #58			Loss: 88.6638
#
#  | Validation Epoch #58			Confidence Mean: 0.71 Variance: 0.0725 Epistemic Uncertainty: 0.0023 Aleatoric Uncertainty: 0.0701
# Saved Epoch 58 as ./checkpoint-houses-bnn-houses-epoch-58.pt
# | Elapsed time : 0:01:00
#
# => Training Epoch #59, LR=0.1000
# | Epoch [ 59/199] Iter[  9/  9]		Iter Loss: -2.9848, Cumulative Loss: 65.4472
# | Validation Epoch #59			Loss: 57.5690
#
#  | Validation Epoch #59			Confidence Mean: 0.89 Variance: 0.0755 Epistemic Uncertainty: 0.0025 Aleatoric Uncertainty: 0.0730
# Saved Epoch 59 as ./checkpoint-houses-bnn-houses-epoch-59.pt
# | Elapsed time : 0:01:01
#
# => Training Epoch #60, LR=0.1000
# | Epoch [ 60/199] Iter[  9/  9]		Iter Loss: -2.6088, Cumulative Loss: 47.7944
# | Validation Epoch #60			Loss: 88.9237
#
#  | Validation Epoch #60			Confidence Mean: 0.65 Variance: 0.0699 Epistemic Uncertainty: 0.0006 Aleatoric Uncertainty: 0.0693
# Saved Epoch 60 as ./checkpoint-houses-bnn-houses-epoch-60.pt
# | Elapsed time : 0:01:02
#
# => Training Epoch #61, LR=0.0200
# | Epoch [ 61/199] Iter[  9/  9]		Iter Loss: -3.3637, Cumulative Loss: 62.6370
# | Validation Epoch #61			Loss: 46.5814
#
#  | Validation Epoch #61			Confidence Mean: 0.78 Variance: 0.0628 Epistemic Uncertainty: 0.0001 Aleatoric Uncertainty: 0.0626
# Saved Epoch 61 as ./checkpoint-houses-bnn-houses-epoch-61.pt
# | Elapsed time : 0:01:03
#
# => Training Epoch #62, LR=0.0200
# | Epoch [ 62/199] Iter[  9/  9]		Iter Loss: -3.0509, Cumulative Loss: 52.8060
# | Validation Epoch #62			Loss: 95.6547
#
#  | Validation Epoch #62			Confidence Mean: 0.70 Variance: 0.0635 Epistemic Uncertainty: 0.0001 Aleatoric Uncertainty: 0.0633
# Saved Epoch 62 as ./checkpoint-houses-bnn-houses-epoch-62.pt
# | Elapsed time : 0:01:04
#
# => Training Epoch #63, LR=0.0200
# | Epoch [ 63/199] Iter[  9/  9]		Iter Loss: -2.9088, Cumulative Loss: 72.9464
# | Validation Epoch #63			Loss: 42.8477
#
#  | Validation Epoch #63			Confidence Mean: 0.78 Variance: 0.0638 Epistemic Uncertainty: 0.0002 Aleatoric Uncertainty: 0.0637
# Saved Epoch 63 as ./checkpoint-houses-bnn-houses-epoch-63.pt
# | Elapsed time : 0:01:05
#
# => Training Epoch #64, LR=0.0200
# | Epoch [ 64/199] Iter[  9/  9]		Iter Loss: -3.2388, Cumulative Loss: 9.7961
# | Validation Epoch #64			Loss: 62.4439
#
#  | Validation Epoch #64			Confidence Mean: 0.74 Variance: 0.0577 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0576
# Saved Epoch 64 as ./checkpoint-houses-bnn-houses-epoch-64.pt
# | Elapsed time : 0:01:06
#
# => Training Epoch #65, LR=0.0200
# | Epoch [ 65/199] Iter[  9/  9]		Iter Loss: -3.1555, Cumulative Loss: 26.9648
# | Validation Epoch #65			Loss: 45.8090
#
#  | Validation Epoch #65			Confidence Mean: 0.71 Variance: 0.0615 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0615
# Saved Epoch 65 as ./checkpoint-houses-bnn-houses-epoch-65.pt
# | Elapsed time : 0:01:07
#
# => Training Epoch #66, LR=0.0200
# | Epoch [ 66/199] Iter[  9/  9]		Iter Loss: -2.7226, Cumulative Loss: 52.4302
# | Validation Epoch #66			Loss: 64.6473
#
#  | Validation Epoch #66			Confidence Mean: 0.75 Variance: 0.0610 Epistemic Uncertainty: 0.0001 Aleatoric Uncertainty: 0.0609
# Saved Epoch 66 as ./checkpoint-houses-bnn-houses-epoch-66.pt
# | Elapsed time : 0:01:08
#
# => Training Epoch #67, LR=0.0200
# | Epoch [ 67/199] Iter[  9/  9]		Iter Loss: -2.9219, Cumulative Loss: 31.1056
# | Validation Epoch #67			Loss: 54.7620
#
#  | Validation Epoch #67			Confidence Mean: 0.77 Variance: 0.0611 Epistemic Uncertainty: 0.0001 Aleatoric Uncertainty: 0.0609
# Saved Epoch 67 as ./checkpoint-houses-bnn-houses-epoch-67.pt
# | Elapsed time : 0:01:09
#
# => Training Epoch #68, LR=0.0200
# | Epoch [ 68/199] Iter[  9/  9]		Iter Loss: -3.2016, Cumulative Loss: 19.1707
# | Validation Epoch #68			Loss: 35.0432
#
#  | Validation Epoch #68			Confidence Mean: 0.71 Variance: 0.0600 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0599
# Saved Epoch 68 as ./checkpoint-houses-bnn-houses-epoch-68.pt
# | Saving Best model...			Loss = 35.04
# | Elapsed time : 0:01:10
#
# => Training Epoch #69, LR=0.0200
# | Epoch [ 69/199] Iter[  9/  9]		Iter Loss: -3.1656, Cumulative Loss: 34.2594
# | Validation Epoch #69			Loss: 33.1731
#
#  | Validation Epoch #69			Confidence Mean: 0.77 Variance: 0.0621 Epistemic Uncertainty: 0.0003 Aleatoric Uncertainty: 0.0616
# Saved Epoch 69 as ./checkpoint-houses-bnn-houses-epoch-69.pt
# | Saving Best model...			Loss = 33.17
# | Elapsed time : 0:01:11
#
# => Training Epoch #70, LR=0.0200
# | Epoch [ 70/199] Iter[  9/  9]		Iter Loss: -2.4527, Cumulative Loss: 35.8661
# | Validation Epoch #70			Loss: 52.1034
#
#  | Validation Epoch #70			Confidence Mean: 0.73 Variance: 0.0552 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0553
# Saved Epoch 70 as ./checkpoint-houses-bnn-houses-epoch-70.pt
# | Elapsed time : 0:01:12
#
# => Training Epoch #71, LR=0.0200
# | Epoch [ 71/199] Iter[  9/  9]		Iter Loss: -2.8834, Cumulative Loss: 27.4672
# | Validation Epoch #71			Loss: 52.0869
#
#  | Validation Epoch #71			Confidence Mean: 0.73 Variance: 0.0618 Epistemic Uncertainty: 0.0001 Aleatoric Uncertainty: 0.0618
# Saved Epoch 71 as ./checkpoint-houses-bnn-houses-epoch-71.pt
# | Elapsed time : 0:01:13
#
# => Training Epoch #72, LR=0.0200
# | Epoch [ 72/199] Iter[  9/  9]		Iter Loss: -3.1064, Cumulative Loss: 48.1529
# | Validation Epoch #72			Loss: 53.4147
#
#  | Validation Epoch #72			Confidence Mean: 0.73 Variance: 0.0606 Epistemic Uncertainty: 0.0001 Aleatoric Uncertainty: 0.0605
# Saved Epoch 72 as ./checkpoint-houses-bnn-houses-epoch-72.pt
# | Elapsed time : 0:01:14
#
# => Training Epoch #73, LR=0.0200
# | Epoch [ 73/199] Iter[  9/  9]		Iter Loss: -2.9673, Cumulative Loss: 16.4403
# | Validation Epoch #73			Loss: 47.0207
#
#  | Validation Epoch #73			Confidence Mean: 0.66 Variance: 0.0589 Epistemic Uncertainty: 0.0001 Aleatoric Uncertainty: 0.0588
# Saved Epoch 73 as ./checkpoint-houses-bnn-houses-epoch-73.pt
# | Elapsed time : 0:01:15
#
# => Training Epoch #74, LR=0.0200
# | Epoch [ 74/199] Iter[  9/  9]		Iter Loss: -3.2427, Cumulative Loss: 36.7815
# | Validation Epoch #74			Loss: 50.1087
#
#  | Validation Epoch #74			Confidence Mean: 0.82 Variance: 0.0629 Epistemic Uncertainty: 0.0003 Aleatoric Uncertainty: 0.0626
# Saved Epoch 74 as ./checkpoint-houses-bnn-houses-epoch-74.pt
# | Elapsed time : 0:01:16
#
# => Training Epoch #75, LR=0.0200
# | Epoch [ 75/199] Iter[  9/  9]		Iter Loss: -3.0830, Cumulative Loss: 43.6478
# | Validation Epoch #75			Loss: 32.2334
#
#  | Validation Epoch #75			Confidence Mean: 0.74 Variance: 0.0578 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0577
# Saved Epoch 75 as ./checkpoint-houses-bnn-houses-epoch-75.pt
# | Saving Best model...			Loss = 32.23
# | Elapsed time : 0:01:17
#
# => Training Epoch #76, LR=0.0200
# | Epoch [ 76/199] Iter[  9/  9]		Iter Loss: -3.1901, Cumulative Loss: 59.1898
# | Validation Epoch #76			Loss: 60.4937
#
#  | Validation Epoch #76			Confidence Mean: 0.74 Variance: 0.0615 Epistemic Uncertainty: 0.0001 Aleatoric Uncertainty: 0.0614
# Saved Epoch 76 as ./checkpoint-houses-bnn-houses-epoch-76.pt
# | Elapsed time : 0:01:18
#
# => Training Epoch #77, LR=0.0200
# | Epoch [ 77/199] Iter[  9/  9]		Iter Loss: -3.0192, Cumulative Loss: 14.8363
# | Validation Epoch #77			Loss: 36.0996
#
#  | Validation Epoch #77			Confidence Mean: 0.70 Variance: 0.0570 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0570
# Saved Epoch 77 as ./checkpoint-houses-bnn-houses-epoch-77.pt
# | Elapsed time : 0:01:19
#
# => Training Epoch #78, LR=0.0200
# | Epoch [ 78/199] Iter[  9/  9]		Iter Loss: -2.7970, Cumulative Loss: 19.5968
# | Validation Epoch #78			Loss: 27.7821
#
#  | Validation Epoch #78			Confidence Mean: 0.84 Variance: 0.0589 Epistemic Uncertainty: 0.0002 Aleatoric Uncertainty: 0.0587
# Saved Epoch 78 as ./checkpoint-houses-bnn-houses-epoch-78.pt
# | Saving Best model...			Loss = 27.78
# | Elapsed time : 0:01:20
#
# => Training Epoch #79, LR=0.0200
# | Epoch [ 79/199] Iter[  9/  9]		Iter Loss: -2.1111, Cumulative Loss: 30.7205
# | Validation Epoch #79			Loss: 55.0624
#
#  | Validation Epoch #79			Confidence Mean: 0.67 Variance: 0.0567 Epistemic Uncertainty: 0.0001 Aleatoric Uncertainty: 0.0566
# Saved Epoch 79 as ./checkpoint-houses-bnn-houses-epoch-79.pt
# | Elapsed time : 0:01:21
#
# => Training Epoch #80, LR=0.0200
# | Epoch [ 80/199] Iter[  9/  9]		Iter Loss: -3.2490, Cumulative Loss: 15.1682
# | Validation Epoch #80			Loss: 56.6255
#
#  | Validation Epoch #80			Confidence Mean: 0.77 Variance: 0.0579 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0578
# Saved Epoch 80 as ./checkpoint-houses-bnn-houses-epoch-80.pt
# | Elapsed time : 0:01:22
#
# => Training Epoch #81, LR=0.0200
# | Epoch [ 81/199] Iter[  9/  9]		Iter Loss: -2.7001, Cumulative Loss: 27.1956
# | Validation Epoch #81			Loss: 61.3921
#
#  | Validation Epoch #81			Confidence Mean: 0.75 Variance: 0.0591 Epistemic Uncertainty: 0.0001 Aleatoric Uncertainty: 0.0589
# Saved Epoch 81 as ./checkpoint-houses-bnn-houses-epoch-81.pt
# | Elapsed time : 0:01:23
#
# => Training Epoch #82, LR=0.0200
# | Epoch [ 82/199] Iter[  9/  9]		Iter Loss: -3.1826, Cumulative Loss: 33.3189
# | Validation Epoch #82			Loss: 68.1750
#
#  | Validation Epoch #82			Confidence Mean: 0.74 Variance: 0.0567 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0567
# Saved Epoch 82 as ./checkpoint-houses-bnn-houses-epoch-82.pt
# | Elapsed time : 0:01:24
#
# => Training Epoch #83, LR=0.0200
# | Epoch [ 83/199] Iter[  9/  9]		Iter Loss: -3.1792, Cumulative Loss: 33.4068
# | Validation Epoch #83			Loss: 32.9614
#
#  | Validation Epoch #83			Confidence Mean: 0.74 Variance: 0.0595 Epistemic Uncertainty: 0.0002 Aleatoric Uncertainty: 0.0594
# Saved Epoch 83 as ./checkpoint-houses-bnn-houses-epoch-83.pt
# | Elapsed time : 0:01:25
#
# => Training Epoch #84, LR=0.0200
# | Epoch [ 84/199] Iter[  9/  9]		Iter Loss: -2.6066, Cumulative Loss: 16.1561
# | Validation Epoch #84			Loss: 65.4291
#
#  | Validation Epoch #84			Confidence Mean: 0.69 Variance: 0.0591 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0593
# Saved Epoch 84 as ./checkpoint-houses-bnn-houses-epoch-84.pt
# | Elapsed time : 0:01:26
#
# => Training Epoch #85, LR=0.0200
# | Epoch [ 85/199] Iter[  9/  9]		Iter Loss: -2.7787, Cumulative Loss: 13.2576
# | Validation Epoch #85			Loss: 26.7827
#
#  | Validation Epoch #85			Confidence Mean: 0.70 Variance: 0.0595 Epistemic Uncertainty: 0.0001 Aleatoric Uncertainty: 0.0593
# Saved Epoch 85 as ./checkpoint-houses-bnn-houses-epoch-85.pt
# | Saving Best model...			Loss = 26.78
# | Elapsed time : 0:01:28
#
# => Training Epoch #86, LR=0.0200
# | Epoch [ 86/199] Iter[  9/  9]		Iter Loss: -2.8827, Cumulative Loss: 1.0700
# | Validation Epoch #86			Loss: 31.0290
#
#  | Validation Epoch #86			Confidence Mean: 0.74 Variance: 0.0603 Epistemic Uncertainty: 0.0001 Aleatoric Uncertainty: 0.0604
# Saved Epoch 86 as ./checkpoint-houses-bnn-houses-epoch-86.pt
# | Elapsed time : 0:01:29
#
# => Training Epoch #87, LR=0.0200
# | Epoch [ 87/199] Iter[  9/  9]		Iter Loss: -2.8305, Cumulative Loss: 45.7639
# | Validation Epoch #87			Loss: 38.1796
#
#  | Validation Epoch #87			Confidence Mean: 0.73 Variance: 0.0641 Epistemic Uncertainty: 0.0001 Aleatoric Uncertainty: 0.0638
# Saved Epoch 87 as ./checkpoint-houses-bnn-houses-epoch-87.pt
# | Elapsed time : 0:01:30
#
# => Training Epoch #88, LR=0.0200
# | Epoch [ 88/199] Iter[  9/  9]		Iter Loss: -3.0922, Cumulative Loss: 25.9023
# | Validation Epoch #88			Loss: 69.1609
#
#  | Validation Epoch #88			Confidence Mean: 0.85 Variance: 0.0584 Epistemic Uncertainty: 0.0001 Aleatoric Uncertainty: 0.0584
# Saved Epoch 88 as ./checkpoint-houses-bnn-houses-epoch-88.pt
# | Elapsed time : 0:01:31
#
# => Training Epoch #89, LR=0.0200
# | Epoch [ 89/199] Iter[  9/  9]		Iter Loss: -3.0580, Cumulative Loss: 26.9277
# | Validation Epoch #89			Loss: 32.1771
#
#  | Validation Epoch #89			Confidence Mean: 0.67 Variance: 0.0637 Epistemic Uncertainty: 0.0002 Aleatoric Uncertainty: 0.0635
# Saved Epoch 89 as ./checkpoint-houses-bnn-houses-epoch-89.pt
# | Elapsed time : 0:01:32
#
# => Training Epoch #90, LR=0.0200
# | Epoch [ 90/199] Iter[  9/  9]		Iter Loss: -3.1552, Cumulative Loss: 43.0541
# | Validation Epoch #90			Loss: 41.6381
#
#  | Validation Epoch #90			Confidence Mean: 0.82 Variance: 0.0654 Epistemic Uncertainty: 0.0002 Aleatoric Uncertainty: 0.0649
# Saved Epoch 90 as ./checkpoint-houses-bnn-houses-epoch-90.pt
# | Elapsed time : 0:01:33
#
# => Training Epoch #91, LR=0.0200
# | Epoch [ 91/199] Iter[  9/  9]		Iter Loss: -3.1821, Cumulative Loss: 29.8892
# | Validation Epoch #91			Loss: 30.5378
#
#  | Validation Epoch #91			Confidence Mean: 0.73 Variance: 0.0635 Epistemic Uncertainty: 0.0003 Aleatoric Uncertainty: 0.0633
# Saved Epoch 91 as ./checkpoint-houses-bnn-houses-epoch-91.pt
# | Elapsed time : 0:01:34
#
# => Training Epoch #92, LR=0.0200
# | Epoch [ 92/199] Iter[  9/  9]		Iter Loss: -3.1116, Cumulative Loss: 22.4199
# | Validation Epoch #92			Loss: 40.1189
#
#  | Validation Epoch #92			Confidence Mean: 0.78 Variance: 0.0600 Epistemic Uncertainty: 0.0001 Aleatoric Uncertainty: 0.0599
# Saved Epoch 92 as ./checkpoint-houses-bnn-houses-epoch-92.pt
# | Elapsed time : 0:01:35
#
# => Training Epoch #93, LR=0.0200
# | Epoch [ 93/199] Iter[  9/  9]		Iter Loss: -2.3947, Cumulative Loss: 19.0674
# | Validation Epoch #93			Loss: 65.2741
#
#  | Validation Epoch #93			Confidence Mean: 0.69 Variance: 0.0612 Epistemic Uncertainty: 0.0002 Aleatoric Uncertainty: 0.0610
# Saved Epoch 93 as ./checkpoint-houses-bnn-houses-epoch-93.pt
# | Elapsed time : 0:01:36
#
# => Training Epoch #94, LR=0.0200
# | Epoch [ 94/199] Iter[  9/  9]		Iter Loss: -2.7610, Cumulative Loss: 21.9048
# | Validation Epoch #94			Loss: 33.4415
#
#  | Validation Epoch #94			Confidence Mean: 0.80 Variance: 0.0583 Epistemic Uncertainty: 0.0001 Aleatoric Uncertainty: 0.0581
# Saved Epoch 94 as ./checkpoint-houses-bnn-houses-epoch-94.pt
# | Elapsed time : 0:01:37
#
# => Training Epoch #95, LR=0.0200
# | Epoch [ 95/199] Iter[  9/  9]		Iter Loss: -2.5222, Cumulative Loss: 24.6123
# | Validation Epoch #95			Loss: 36.9900
#
#  | Validation Epoch #95			Confidence Mean: 0.77 Variance: 0.0647 Epistemic Uncertainty: 0.0004 Aleatoric Uncertainty: 0.0642
# Saved Epoch 95 as ./checkpoint-houses-bnn-houses-epoch-95.pt
# | Elapsed time : 0:01:38
#
# => Training Epoch #96, LR=0.0200
# | Epoch [ 96/199] Iter[  9/  9]		Iter Loss: -3.2738, Cumulative Loss: 26.8595
# | Validation Epoch #96			Loss: 51.3329
#
#  | Validation Epoch #96			Confidence Mean: 0.77 Variance: 0.0587 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0586
# Saved Epoch 96 as ./checkpoint-houses-bnn-houses-epoch-96.pt
# | Elapsed time : 0:01:39
#
# => Training Epoch #97, LR=0.0200
# | Epoch [ 97/199] Iter[  9/  9]		Iter Loss: -2.6613, Cumulative Loss: 37.0595
# | Validation Epoch #97			Loss: 64.4744
#
#  | Validation Epoch #97			Confidence Mean: 0.74 Variance: 0.0668 Epistemic Uncertainty: 0.0004 Aleatoric Uncertainty: 0.0664
# Saved Epoch 97 as ./checkpoint-houses-bnn-houses-epoch-97.pt
# | Elapsed time : 0:01:40
#
# => Training Epoch #98, LR=0.0200
# | Epoch [ 98/199] Iter[  9/  9]		Iter Loss: -3.0069, Cumulative Loss: 47.1453
# | Validation Epoch #98			Loss: 35.6141
#
#  | Validation Epoch #98			Confidence Mean: 0.73 Variance: 0.0607 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0604
# Saved Epoch 98 as ./checkpoint-houses-bnn-houses-epoch-98.pt
# | Elapsed time : 0:01:41
#
# => Training Epoch #99, LR=0.0200
# | Epoch [ 99/199] Iter[  9/  9]		Iter Loss: -3.0599, Cumulative Loss: 31.1019
# | Validation Epoch #99			Loss: 47.7217
#
#  | Validation Epoch #99			Confidence Mean: 0.84 Variance: 0.0656 Epistemic Uncertainty: 0.0007 Aleatoric Uncertainty: 0.0651
# Saved Epoch 99 as ./checkpoint-houses-bnn-houses-epoch-99.pt
# | Elapsed time : 0:01:42
#
# => Training Epoch #100, LR=0.0200
# | Epoch [100/199] Iter[  9/  9]		Iter Loss: -3.0078, Cumulative Loss: 27.5583
# | Validation Epoch #100			Loss: 51.2460
#
#  | Validation Epoch #100			Confidence Mean: 0.64 Variance: 0.0552 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0551
# Saved Epoch 100 as ./checkpoint-houses-bnn-houses-epoch-100.pt
# | Elapsed time : 0:01:43
#
# => Training Epoch #101, LR=0.0200
# | Epoch [101/199] Iter[  9/  9]		Iter Loss: -3.2157, Cumulative Loss: 17.8192
# | Validation Epoch #101			Loss: 56.1641
#
#  | Validation Epoch #101			Confidence Mean: 0.73 Variance: 0.0552 Epistemic Uncertainty: 0.0001 Aleatoric Uncertainty: 0.0550
# Saved Epoch 101 as ./checkpoint-houses-bnn-houses-epoch-101.pt
# | Elapsed time : 0:01:44
#
# => Training Epoch #102, LR=0.0200
# | Epoch [102/199] Iter[  9/  9]		Iter Loss: -2.6767, Cumulative Loss: 14.4228
# | Validation Epoch #102			Loss: 45.7107
#
#  | Validation Epoch #102			Confidence Mean: 0.77 Variance: 0.0553 Epistemic Uncertainty: 0.0001 Aleatoric Uncertainty: 0.0551
# Saved Epoch 102 as ./checkpoint-houses-bnn-houses-epoch-102.pt
# | Elapsed time : 0:01:45
#
# => Training Epoch #103, LR=0.0200
# | Epoch [103/199] Iter[  9/  9]		Iter Loss: -2.7421, Cumulative Loss: 17.5126
# | Validation Epoch #103			Loss: 62.8518
#
#  | Validation Epoch #103			Confidence Mean: 0.74 Variance: 0.0567 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0566
# Saved Epoch 103 as ./checkpoint-houses-bnn-houses-epoch-103.pt
# | Elapsed time : 0:01:46
#
# => Training Epoch #104, LR=0.0200
# | Epoch [104/199] Iter[  9/  9]		Iter Loss: -3.2251, Cumulative Loss: 15.2963
# | Validation Epoch #104			Loss: 46.6217
#
#  | Validation Epoch #104			Confidence Mean: 0.68 Variance: 0.0587 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0587
# Saved Epoch 104 as ./checkpoint-houses-bnn-houses-epoch-104.pt
# | Elapsed time : 0:01:47
#
# => Training Epoch #105, LR=0.0200
# | Epoch [105/199] Iter[  9/  9]		Iter Loss: -2.9260, Cumulative Loss: 22.3098
# | Validation Epoch #105			Loss: 48.8485
#
#  | Validation Epoch #105			Confidence Mean: 0.72 Variance: 0.0666 Epistemic Uncertainty: 0.0002 Aleatoric Uncertainty: 0.0663
# Saved Epoch 105 as ./checkpoint-houses-bnn-houses-epoch-105.pt
# | Elapsed time : 0:01:48
#
# => Training Epoch #106, LR=0.0200
# | Epoch [106/199] Iter[  9/  9]		Iter Loss: -2.8997, Cumulative Loss: 38.2161
# | Validation Epoch #106			Loss: 53.6636
#
#  | Validation Epoch #106			Confidence Mean: 0.72 Variance: 0.0621 Epistemic Uncertainty: 0.0002 Aleatoric Uncertainty: 0.0620
# Saved Epoch 106 as ./checkpoint-houses-bnn-houses-epoch-106.pt
# | Elapsed time : 0:01:49
#
# => Training Epoch #107, LR=0.0200
# | Epoch [107/199] Iter[  9/  9]		Iter Loss: -3.0075, Cumulative Loss: 53.0545
# | Validation Epoch #107			Loss: 62.0835
#
#  | Validation Epoch #107			Confidence Mean: 0.77 Variance: 0.0650 Epistemic Uncertainty: 0.0002 Aleatoric Uncertainty: 0.0649
# Saved Epoch 107 as ./checkpoint-houses-bnn-houses-epoch-107.pt
# | Elapsed time : 0:01:50
#
# => Training Epoch #108, LR=0.0200
# | Epoch [108/199] Iter[  9/  9]		Iter Loss: -3.2603, Cumulative Loss: 30.8740
# | Validation Epoch #108			Loss: 63.3729
#
#  | Validation Epoch #108			Confidence Mean: 0.75 Variance: 0.0638 Epistemic Uncertainty: 0.0001 Aleatoric Uncertainty: 0.0638
# Saved Epoch 108 as ./checkpoint-houses-bnn-houses-epoch-108.pt
# | Elapsed time : 0:01:51
#
# => Training Epoch #109, LR=0.0200
# | Epoch [109/199] Iter[  9/  9]		Iter Loss: -2.8970, Cumulative Loss: 21.8416
# | Validation Epoch #109			Loss: 17.1301
#
#  | Validation Epoch #109			Confidence Mean: 0.76 Variance: 0.0652 Epistemic Uncertainty: 0.0005 Aleatoric Uncertainty: 0.0646
# Saved Epoch 109 as ./checkpoint-houses-bnn-houses-epoch-109.pt
# | Saving Best model...			Loss = 17.13
# | Elapsed time : 0:01:52
#
# => Training Epoch #110, LR=0.0200
# | Epoch [110/199] Iter[  9/  9]		Iter Loss: -2.8389, Cumulative Loss: 24.5301
# | Validation Epoch #110			Loss: 46.6021
#
#  | Validation Epoch #110			Confidence Mean: 0.71 Variance: 0.0625 Epistemic Uncertainty: 0.0001 Aleatoric Uncertainty: 0.0624
# Saved Epoch 110 as ./checkpoint-houses-bnn-houses-epoch-110.pt
# | Elapsed time : 0:01:53
#
# => Training Epoch #111, LR=0.0200
# | Epoch [111/199] Iter[  9/  9]		Iter Loss: -3.1431, Cumulative Loss: 40.5141
# | Validation Epoch #111			Loss: 62.7438
#
#  | Validation Epoch #111			Confidence Mean: 0.68 Variance: 0.0605 Epistemic Uncertainty: 0.0001 Aleatoric Uncertainty: 0.0606
# Saved Epoch 111 as ./checkpoint-houses-bnn-houses-epoch-111.pt
# | Elapsed time : 0:01:54
#
# => Training Epoch #112, LR=0.0200
# | Epoch [112/199] Iter[  9/  9]		Iter Loss: -2.8776, Cumulative Loss: 16.2350
# | Validation Epoch #112			Loss: 41.5163
#
#  | Validation Epoch #112			Confidence Mean: 0.80 Variance: 0.0555 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0557
# Saved Epoch 112 as ./checkpoint-houses-bnn-houses-epoch-112.pt
# | Elapsed time : 0:01:55
#
# => Training Epoch #113, LR=0.0200
# | Epoch [113/199] Iter[  9/  9]		Iter Loss: -2.9977, Cumulative Loss: 19.4758
# | Validation Epoch #113			Loss: 57.1224
#
#  | Validation Epoch #113			Confidence Mean: 0.68 Variance: 0.0616 Epistemic Uncertainty: 0.0001 Aleatoric Uncertainty: 0.0615
# Saved Epoch 113 as ./checkpoint-houses-bnn-houses-epoch-113.pt
# | Elapsed time : 0:01:56
#
# => Training Epoch #114, LR=0.0200
# | Epoch [114/199] Iter[  9/  9]		Iter Loss: -3.4691, Cumulative Loss: 17.9480
# | Validation Epoch #114			Loss: 45.6351
#
#  | Validation Epoch #114			Confidence Mean: 0.75 Variance: 0.0605 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0606
# Saved Epoch 114 as ./checkpoint-houses-bnn-houses-epoch-114.pt
# | Elapsed time : 0:01:57
#
# => Training Epoch #115, LR=0.0200
# | Epoch [115/199] Iter[  9/  9]		Iter Loss: -2.9278, Cumulative Loss: 21.0096
# | Validation Epoch #115			Loss: 24.5956
#
#  | Validation Epoch #115			Confidence Mean: 0.72 Variance: 0.0668 Epistemic Uncertainty: 0.0002 Aleatoric Uncertainty: 0.0666
# Saved Epoch 115 as ./checkpoint-houses-bnn-houses-epoch-115.pt
# | Elapsed time : 0:01:58
#
# => Training Epoch #116, LR=0.0200
# | Epoch [116/199] Iter[  9/  9]		Iter Loss: -2.8042, Cumulative Loss: 22.7353
# | Validation Epoch #116			Loss: 27.7667
#
#  | Validation Epoch #116			Confidence Mean: 0.72 Variance: 0.0598 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0600
# Saved Epoch 116 as ./checkpoint-houses-bnn-houses-epoch-116.pt
# | Elapsed time : 0:01:59
#
# => Training Epoch #117, LR=0.0200
# | Epoch [117/199] Iter[  9/  9]		Iter Loss: -2.5574, Cumulative Loss: 19.0254
# | Validation Epoch #117			Loss: 53.9518
#
#  | Validation Epoch #117			Confidence Mean: 0.71 Variance: 0.0636 Epistemic Uncertainty: 0.0001 Aleatoric Uncertainty: 0.0634
# Saved Epoch 117 as ./checkpoint-houses-bnn-houses-epoch-117.pt
# | Elapsed time : 0:02:00
#
# => Training Epoch #118, LR=0.0200
# | Epoch [118/199] Iter[  9/  9]		Iter Loss: -2.9376, Cumulative Loss: 25.6008
# | Validation Epoch #118			Loss: 30.9769
#
#  | Validation Epoch #118			Confidence Mean: 0.73 Variance: 0.0642 Epistemic Uncertainty: 0.0003 Aleatoric Uncertainty: 0.0640
# Saved Epoch 118 as ./checkpoint-houses-bnn-houses-epoch-118.pt
# | Elapsed time : 0:02:01
#
# => Training Epoch #119, LR=0.0200
# | Epoch [119/199] Iter[  9/  9]		Iter Loss: -2.8879, Cumulative Loss: 11.0181
# | Validation Epoch #119			Loss: 35.0388
#
#  | Validation Epoch #119			Confidence Mean: 0.69 Variance: 0.0582 Epistemic Uncertainty: 0.0001 Aleatoric Uncertainty: 0.0581
# Saved Epoch 119 as ./checkpoint-houses-bnn-houses-epoch-119.pt
# | Elapsed time : 0:02:02
#
# => Training Epoch #120, LR=0.0200
# | Epoch [120/199] Iter[  9/  9]		Iter Loss: -3.1034, Cumulative Loss: 19.0275
# | Validation Epoch #120			Loss: 45.5212
#
#  | Validation Epoch #120			Confidence Mean: 0.68 Variance: 0.0607 Epistemic Uncertainty: 0.0002 Aleatoric Uncertainty: 0.0604
# Saved Epoch 120 as ./checkpoint-houses-bnn-houses-epoch-120.pt
# | Elapsed time : 0:02:03
#
# => Training Epoch #121, LR=0.0040
# | Epoch [121/199] Iter[  9/  9]		Iter Loss: -3.3576, Cumulative Loss: 42.6678
# | Validation Epoch #121			Loss: 62.1025
#
#  | Validation Epoch #121			Confidence Mean: 0.73 Variance: 0.0566 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0567
# Saved Epoch 121 as ./checkpoint-houses-bnn-houses-epoch-121.pt
# | Elapsed time : 0:02:04
#
# => Training Epoch #122, LR=0.0040
# | Epoch [122/199] Iter[  9/  9]		Iter Loss: -3.0526, Cumulative Loss: 30.9882
# | Validation Epoch #122			Loss: 66.8595
#
#  | Validation Epoch #122			Confidence Mean: 0.75 Variance: 0.0568 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0568
# Saved Epoch 122 as ./checkpoint-houses-bnn-houses-epoch-122.pt
# | Elapsed time : 0:02:05
#
# => Training Epoch #123, LR=0.0040
# | Epoch [123/199] Iter[  9/  9]		Iter Loss: -3.2705, Cumulative Loss: 28.1395
# | Validation Epoch #123			Loss: 38.0313
#
#  | Validation Epoch #123			Confidence Mean: 0.74 Variance: 0.0578 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0577
# Saved Epoch 123 as ./checkpoint-houses-bnn-houses-epoch-123.pt
# | Elapsed time : 0:02:06
#
# => Training Epoch #124, LR=0.0040
# | Epoch [124/199] Iter[  9/  9]		Iter Loss: -3.2129, Cumulative Loss: 47.7706
# | Validation Epoch #124			Loss: 43.2398
#
#  | Validation Epoch #124			Confidence Mean: 0.73 Variance: 0.0574 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0574
# Saved Epoch 124 as ./checkpoint-houses-bnn-houses-epoch-124.pt
# | Elapsed time : 0:02:07
#
# => Training Epoch #125, LR=0.0040
# | Epoch [125/199] Iter[  9/  9]		Iter Loss: -3.0760, Cumulative Loss: 28.3343
# | Validation Epoch #125			Loss: 40.6813
#
#  | Validation Epoch #125			Confidence Mean: 0.71 Variance: 0.0553 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0554
# Saved Epoch 125 as ./checkpoint-houses-bnn-houses-epoch-125.pt
# | Elapsed time : 0:02:08
#
# => Training Epoch #126, LR=0.0040
# | Epoch [126/199] Iter[  9/  9]		Iter Loss: -2.8307, Cumulative Loss: 11.4502
# | Validation Epoch #126			Loss: 20.2033
#
#  | Validation Epoch #126			Confidence Mean: 0.72 Variance: 0.0563 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0563
# Saved Epoch 126 as ./checkpoint-houses-bnn-houses-epoch-126.pt
# | Elapsed time : 0:02:09
#
# => Training Epoch #127, LR=0.0040
# | Epoch [127/199] Iter[  9/  9]		Iter Loss: -3.2081, Cumulative Loss: 30.9484
# | Validation Epoch #127			Loss: 44.4221
#
#  | Validation Epoch #127			Confidence Mean: 0.73 Variance: 0.0574 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0574
# Saved Epoch 127 as ./checkpoint-houses-bnn-houses-epoch-127.pt
# | Elapsed time : 0:02:10
#
# => Training Epoch #128, LR=0.0040
# | Epoch [128/199] Iter[  9/  9]		Iter Loss: -3.2424, Cumulative Loss: 39.3621
# | Validation Epoch #128			Loss: 81.2183
#
#  | Validation Epoch #128			Confidence Mean: 0.75 Variance: 0.0565 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0565
# Saved Epoch 128 as ./checkpoint-houses-bnn-houses-epoch-128.pt
# | Elapsed time : 0:02:11
#
# => Training Epoch #129, LR=0.0040
# | Epoch [129/199] Iter[  9/  9]		Iter Loss: -2.7550, Cumulative Loss: 35.2638
# | Validation Epoch #129			Loss: 46.8454
#
#  | Validation Epoch #129			Confidence Mean: 0.75 Variance: 0.0562 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0562
# Saved Epoch 129 as ./checkpoint-houses-bnn-houses-epoch-129.pt
# | Elapsed time : 0:02:12
#
# => Training Epoch #130, LR=0.0040
# | Epoch [130/199] Iter[  9/  9]		Iter Loss: -2.8115, Cumulative Loss: 30.0377
# ...
# Saved Epoch 156 as ./checkpoint-houses-bnn-houses-epoch-156.pt
# | Elapsed time : 0:02:40
#
# => Training Epoch #157, LR=0.0040
# | Epoch [157/199] Iter[  9/  9]		Iter Loss: -3.4236, Cumulative Loss: 18.0830
# | Validation Epoch #157			Loss: 48.2763
#
#  | Validation Epoch #157			Confidence Mean: 0.74 Variance: 0.0572 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0571
# Saved Epoch 157 as ./checkpoint-houses-bnn-houses-epoch-157.pt
# | Elapsed time : 0:02:41
#
# => Training Epoch #158, LR=0.0040
# | Epoch [158/199] Iter[  9/  9]		Iter Loss: -3.1742, Cumulative Loss: 10.6185
# | Validation Epoch #158			Loss: 38.9481
#
#  | Validation Epoch #158			Confidence Mean: 0.75 Variance: 0.0578 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0576
# Saved Epoch 158 as ./checkpoint-houses-bnn-houses-epoch-158.pt
# | Elapsed time : 0:02:42
#
# => Training Epoch #159, LR=0.0040
# | Epoch [159/199] Iter[  9/  9]		Iter Loss: -3.1972, Cumulative Loss: 32.5913
# | Validation Epoch #159			Loss: 23.4651
#
#  | Validation Epoch #159			Confidence Mean: 0.76 Variance: 0.0570 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0571
# Saved Epoch 159 as ./checkpoint-houses-bnn-houses-epoch-159.pt
# | Elapsed time : 0:02:43
#
# => Training Epoch #160, LR=0.0040
# | Epoch [160/199] Iter[  9/  9]		Iter Loss: -3.0978, Cumulative Loss: 14.6372
# | Validation Epoch #160			Loss: 41.7627
#
#  | Validation Epoch #160			Confidence Mean: 0.75 Variance: 0.0591 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0591
# Saved Epoch 160 as ./checkpoint-houses-bnn-houses-epoch-160.pt
# | Elapsed time : 0:02:44
#
# => Training Epoch #161, LR=0.0008
# | Epoch [161/199] Iter[  9/  9]		Iter Loss: -3.3837, Cumulative Loss: 17.6052
# | Validation Epoch #161			Loss: 39.8350
#
#  | Validation Epoch #161			Confidence Mean: 0.74 Variance: 0.0576 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0576
# Saved Epoch 161 as ./checkpoint-houses-bnn-houses-epoch-161.pt
# | Elapsed time : 0:02:45
#
# => Training Epoch #162, LR=0.0008
# | Epoch [162/199] Iter[  9/  9]		Iter Loss: -3.1363, Cumulative Loss: 21.5267
# | Validation Epoch #162			Loss: 36.1719
#
#  | Validation Epoch #162			Confidence Mean: 0.74 Variance: 0.0574 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0575
# Saved Epoch 162 as ./checkpoint-houses-bnn-houses-epoch-162.pt
# | Elapsed time : 0:02:46
#
# => Training Epoch #163, LR=0.0008
# | Epoch [163/199] Iter[  9/  9]		Iter Loss: -2.6403, Cumulative Loss: 6.6049
# | Validation Epoch #163			Loss: 39.5631
#
#  | Validation Epoch #163			Confidence Mean: 0.75 Variance: 0.0573 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0573
# Saved Epoch 163 as ./checkpoint-houses-bnn-houses-epoch-163.pt
# | Elapsed time : 0:02:47
#
# => Training Epoch #164, LR=0.0008
# | Epoch [164/199] Iter[  9/  9]		Iter Loss: -2.2885, Cumulative Loss: 24.5743
# | Validation Epoch #164			Loss: 51.0666
#
#  | Validation Epoch #164			Confidence Mean: 0.74 Variance: 0.0573 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0571
# Saved Epoch 164 as ./checkpoint-houses-bnn-houses-epoch-164.pt
# | Elapsed time : 0:02:48
#
# => Training Epoch #165, LR=0.0008
# | Epoch [165/199] Iter[  9/  9]		Iter Loss: -3.2146, Cumulative Loss: 25.5377
# | Validation Epoch #165			Loss: 30.2205
#
#  | Validation Epoch #165			Confidence Mean: 0.73 Variance: 0.0571 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0571
# Saved Epoch 165 as ./checkpoint-houses-bnn-houses-epoch-165.pt
# | Elapsed time : 0:02:49
#
# => Training Epoch #166, LR=0.0008
# | Epoch [166/199] Iter[  9/  9]		Iter Loss: -3.0386, Cumulative Loss: 32.8965
# | Validation Epoch #166			Loss: 45.4989
#
#  | Validation Epoch #166			Confidence Mean: 0.73 Variance: 0.0574 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0573
# Saved Epoch 166 as ./checkpoint-houses-bnn-houses-epoch-166.pt
# | Elapsed time : 0:02:50
#
# => Training Epoch #167, LR=0.0008
# | Epoch [167/199] Iter[  9/  9]		Iter Loss: -2.8730, Cumulative Loss: 13.3197
# | Validation Epoch #167			Loss: 33.0603
#
#  | Validation Epoch #167			Confidence Mean: 0.73 Variance: 0.0573 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0572
# Saved Epoch 167 as ./checkpoint-houses-bnn-houses-epoch-167.pt
# | Elapsed time : 0:02:51
#
# => Training Epoch #168, LR=0.0008
# | Epoch [168/199] Iter[  9/  9]		Iter Loss: -2.8533, Cumulative Loss: 9.9530
# | Validation Epoch #168			Loss: 56.1704
#
#  | Validation Epoch #168			Confidence Mean: 0.72 Variance: 0.0575 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0576
# Saved Epoch 168 as ./checkpoint-houses-bnn-houses-epoch-168.pt
# | Elapsed time : 0:02:52
#
# => Training Epoch #169, LR=0.0008
# | Epoch [169/199] Iter[  9/  9]		Iter Loss: -2.8126, Cumulative Loss: 57.3737
# | Validation Epoch #169			Loss: 38.8970
#
#  | Validation Epoch #169			Confidence Mean: 0.72 Variance: 0.0570 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0571
# Saved Epoch 169 as ./checkpoint-houses-bnn-houses-epoch-169.pt
# | Elapsed time : 0:02:53
#
# => Training Epoch #170, LR=0.0008
# | Epoch [170/199] Iter[  9/  9]		Iter Loss: -3.0152, Cumulative Loss: 32.2677
# | Validation Epoch #170			Loss: 24.8407
#
#  | Validation Epoch #170			Confidence Mean: 0.73 Variance: 0.0572 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0571
# Saved Epoch 170 as ./checkpoint-houses-bnn-houses-epoch-170.pt
# | Elapsed time : 0:02:54
#
# => Training Epoch #171, LR=0.0008
# | Epoch [171/199] Iter[  9/  9]		Iter Loss: -3.3139, Cumulative Loss: 15.1535
# | Validation Epoch #171			Loss: 40.3118
#
#  | Validation Epoch #171			Confidence Mean: 0.74 Variance: 0.0567 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0568
# Saved Epoch 171 as ./checkpoint-houses-bnn-houses-epoch-171.pt
# | Elapsed time : 0:02:55
#
# => Training Epoch #172, LR=0.0008
# | Epoch [172/199] Iter[  9/  9]		Iter Loss: -2.9009, Cumulative Loss: 0.1408
# | Validation Epoch #172			Loss: 31.2761
#
#  | Validation Epoch #172			Confidence Mean: 0.74 Variance: 0.0570 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0570
# Saved Epoch 172 as ./checkpoint-houses-bnn-houses-epoch-172.pt
# | Elapsed time : 0:02:56
#
# => Training Epoch #173, LR=0.0008
# | Epoch [173/199] Iter[  9/  9]		Iter Loss: -2.8421, Cumulative Loss: 11.5838
# | Validation Epoch #173			Loss: 24.1043
#
#  | Validation Epoch #173			Confidence Mean: 0.73 Variance: 0.0569 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0570
# Saved Epoch 173 as ./checkpoint-houses-bnn-houses-epoch-173.pt
# | Elapsed time : 0:02:57
#
# => Training Epoch #174, LR=0.0008
# | Epoch [174/199] Iter[  9/  9]		Iter Loss: -2.8319, Cumulative Loss: 21.1463
# | Validation Epoch #174			Loss: 50.9562
#
#  | Validation Epoch #174			Confidence Mean: 0.74 Variance: 0.0567 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0567
# Saved Epoch 174 as ./checkpoint-houses-bnn-houses-epoch-174.pt
# | Elapsed time : 0:02:58
#
# => Training Epoch #175, LR=0.0008
# | Epoch [175/199] Iter[  9/  9]		Iter Loss: -2.8272, Cumulative Loss: 29.8019
# | Validation Epoch #175			Loss: 24.0171
#
#  | Validation Epoch #175			Confidence Mean: 0.74 Variance: 0.0566 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0565
# Saved Epoch 175 as ./checkpoint-houses-bnn-houses-epoch-175.pt
# | Elapsed time : 0:02:59
#
# => Training Epoch #176, LR=0.0008
# | Epoch [176/199] Iter[  9/  9]		Iter Loss: -3.1602, Cumulative Loss: 5.5859
# | Validation Epoch #176			Loss: 37.1039
#
#  | Validation Epoch #176			Confidence Mean: 0.75 Variance: 0.0565 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0564
# Saved Epoch 176 as ./checkpoint-houses-bnn-houses-epoch-176.pt
# | Elapsed time : 0:03:01
#
# => Training Epoch #177, LR=0.0008
# | Epoch [177/199] Iter[  9/  9]		Iter Loss: -3.2832, Cumulative Loss: 12.6302
# | Validation Epoch #177			Loss: 51.8572
#
#  | Validation Epoch #177			Confidence Mean: 0.75 Variance: 0.0566 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0566
# Saved Epoch 177 as ./checkpoint-houses-bnn-houses-epoch-177.pt
# | Elapsed time : 0:03:02
#
# => Training Epoch #178, LR=0.0008
# | Epoch [178/199] Iter[  9/  9]		Iter Loss: -2.7163, Cumulative Loss: 26.0670
# | Validation Epoch #178			Loss: 33.5490
#
#  | Validation Epoch #178			Confidence Mean: 0.75 Variance: 0.0566 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0566
# Saved Epoch 178 as ./checkpoint-houses-bnn-houses-epoch-178.pt
# | Elapsed time : 0:03:03
#
# => Training Epoch #179, LR=0.0008
# | Epoch [179/199] Iter[  9/  9]		Iter Loss: -3.2548, Cumulative Loss: 23.0719
# | Validation Epoch #179			Loss: 37.7214
#
#  | Validation Epoch #179			Confidence Mean: 0.75 Variance: 0.0567 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0568
# Saved Epoch 179 as ./checkpoint-houses-bnn-houses-epoch-179.pt
# | Elapsed time : 0:03:04
#
# => Training Epoch #180, LR=0.0008
# | Epoch [180/199] Iter[  9/  9]		Iter Loss: -3.1025, Cumulative Loss: 19.4684
# | Validation Epoch #180			Loss: 24.8535
#
#  | Validation Epoch #180			Confidence Mean: 0.75 Variance: 0.0564 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0564
# Saved Epoch 180 as ./checkpoint-houses-bnn-houses-epoch-180.pt
# | Elapsed time : 0:03:05
#
# => Training Epoch #181, LR=0.0008
# | Epoch [181/199] Iter[  9/  9]		Iter Loss: -3.0569, Cumulative Loss: 21.5135
# | Validation Epoch #181			Loss: 46.1820
#
#  | Validation Epoch #181			Confidence Mean: 0.75 Variance: 0.0564 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0564
# Saved Epoch 181 as ./checkpoint-houses-bnn-houses-epoch-181.pt
# | Elapsed time : 0:03:06
#
# => Training Epoch #182, LR=0.0008
# | Epoch [182/199] Iter[  9/  9]		Iter Loss: -3.2142, Cumulative Loss: 18.4664
# | Validation Epoch #182			Loss: 51.8662
#
#  | Validation Epoch #182			Confidence Mean: 0.75 Variance: 0.0563 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0564
# Saved Epoch 182 as ./checkpoint-houses-bnn-houses-epoch-182.pt
# | Elapsed time : 0:03:07
#
# => Training Epoch #183, LR=0.0008
# | Epoch [183/199] Iter[  9/  9]		Iter Loss: -3.0804, Cumulative Loss: 18.5761
# | Validation Epoch #183			Loss: 46.1911
#
#  | Validation Epoch #183			Confidence Mean: 0.75 Variance: 0.0565 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0565
# Saved Epoch 183 as ./checkpoint-houses-bnn-houses-epoch-183.pt
# | Elapsed time : 0:03:08
#
# => Training Epoch #184, LR=0.0008
# | Epoch [184/199] Iter[  9/  9]		Iter Loss: -3.1547, Cumulative Loss: 32.5000
# | Validation Epoch #184			Loss: 24.0489
#
#  | Validation Epoch #184			Confidence Mean: 0.75 Variance: 0.0563 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0564
# Saved Epoch 184 as ./checkpoint-houses-bnn-houses-epoch-184.pt
# | Elapsed time : 0:03:09
#
# => Training Epoch #185, LR=0.0008
# | Epoch [185/199] Iter[  9/  9]		Iter Loss: -3.2867, Cumulative Loss: 33.7089
# | Validation Epoch #185			Loss: 47.8751
#
#  | Validation Epoch #185			Confidence Mean: 0.74 Variance: 0.0563 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0562
# Saved Epoch 185 as ./checkpoint-houses-bnn-houses-epoch-185.pt
# | Elapsed time : 0:03:10
#
# => Training Epoch #186, LR=0.0008
# | Epoch [186/199] Iter[  9/  9]		Iter Loss: -3.1746, Cumulative Loss: 26.5357
# | Validation Epoch #186			Loss: 28.2047
#
#  | Validation Epoch #186			Confidence Mean: 0.75 Variance: 0.0563 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0562
# Saved Epoch 186 as ./checkpoint-houses-bnn-houses-epoch-186.pt
# | Elapsed time : 0:03:11
#
# => Training Epoch #187, LR=0.0008
# | Epoch [187/199] Iter[  9/  9]		Iter Loss: -2.8139, Cumulative Loss: 19.7377
# | Validation Epoch #187			Loss: 47.0696
#
#  | Validation Epoch #187			Confidence Mean: 0.75 Variance: 0.0564 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0564
# Saved Epoch 187 as ./checkpoint-houses-bnn-houses-epoch-187.pt
# | Elapsed time : 0:03:12
#
# => Training Epoch #188, LR=0.0008
# | Epoch [188/199] Iter[  9/  9]		Iter Loss: -3.1200, Cumulative Loss: 24.3589
# | Validation Epoch #188			Loss: 43.6945
#
#  | Validation Epoch #188			Confidence Mean: 0.74 Variance: 0.0564 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0563
# Saved Epoch 188 as ./checkpoint-houses-bnn-houses-epoch-188.pt
# | Elapsed time : 0:03:13
#
# => Training Epoch #189, LR=0.0008
# | Epoch [189/199] Iter[  9/  9]		Iter Loss: -3.0405, Cumulative Loss: 9.1225
# | Validation Epoch #189			Loss: 38.6972
#
#  | Validation Epoch #189			Confidence Mean: 0.75 Variance: 0.0562 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0562
# Saved Epoch 189 as ./checkpoint-houses-bnn-houses-epoch-189.pt
# | Elapsed time : 0:03:14
#
# => Training Epoch #190, LR=0.0008
# | Epoch [190/199] Iter[  9/  9]		Iter Loss: -2.4903, Cumulative Loss: 0.4642
# | Validation Epoch #190			Loss: 33.5187
#
#  | Validation Epoch #190			Confidence Mean: 0.75 Variance: 0.0565 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0564
# Saved Epoch 190 as ./checkpoint-houses-bnn-houses-epoch-190.pt
# | Elapsed time : 0:03:15
#
# => Training Epoch #191, LR=0.0008
# | Epoch [191/199] Iter[  9/  9]		Iter Loss: -2.7830, Cumulative Loss: 2.7929
# | Validation Epoch #191			Loss: 34.2437
#
#  | Validation Epoch #191			Confidence Mean: 0.74 Variance: 0.0564 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0562
# Saved Epoch 191 as ./checkpoint-houses-bnn-houses-epoch-191.pt
# | Elapsed time : 0:03:16
#
# => Training Epoch #192, LR=0.0008
# | Epoch [192/199] Iter[  9/  9]		Iter Loss: -3.1394, Cumulative Loss: 23.7330
# | Validation Epoch #192			Loss: 47.9238
#
#  | Validation Epoch #192			Confidence Mean: 0.75 Variance: 0.0569 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0568
# Saved Epoch 192 as ./checkpoint-houses-bnn-houses-epoch-192.pt
# | Elapsed time : 0:03:17
#
# => Training Epoch #193, LR=0.0008
# | Epoch [193/199] Iter[  9/  9]		Iter Loss: -2.4799, Cumulative Loss: 25.7089
# | Validation Epoch #193			Loss: 44.0088
#
#  | Validation Epoch #193			Confidence Mean: 0.74 Variance: 0.0567 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0566
# Saved Epoch 193 as ./checkpoint-houses-bnn-houses-epoch-193.pt
# | Elapsed time : 0:03:18
#
# => Training Epoch #194, LR=0.0008
# | Epoch [194/199] Iter[  9/  9]		Iter Loss: -2.9930, Cumulative Loss: 23.7294
# | Validation Epoch #194			Loss: 33.6292
#
#  | Validation Epoch #194			Confidence Mean: 0.73 Variance: 0.0565 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0565
# Saved Epoch 194 as ./checkpoint-houses-bnn-houses-epoch-194.pt
# | Elapsed time : 0:03:19
#
# => Training Epoch #195, LR=0.0008
# | Epoch [195/199] Iter[  9/  9]		Iter Loss: -3.1161, Cumulative Loss: 31.4442
# | Validation Epoch #195			Loss: 44.6505
#
#  | Validation Epoch #195			Confidence Mean: 0.73 Variance: 0.0561 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0561
# Saved Epoch 195 as ./checkpoint-houses-bnn-houses-epoch-195.pt
# | Elapsed time : 0:03:20
#
# => Training Epoch #196, LR=0.0008
# | Epoch [196/199] Iter[  9/  9]		Iter Loss: -3.0227, Cumulative Loss: 28.2433
# | Validation Epoch #196			Loss: 28.6326
#
#  | Validation Epoch #196			Confidence Mean: 0.74 Variance: 0.0563 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0562
# Saved Epoch 196 as ./checkpoint-houses-bnn-houses-epoch-196.pt
# | Elapsed time : 0:03:21
#
# => Training Epoch #197, LR=0.0008
# | Epoch [197/199] Iter[  9/  9]		Iter Loss: -3.0184, Cumulative Loss: 22.8800
# | Validation Epoch #197			Loss: 37.6748
#
#  | Validation Epoch #197			Confidence Mean: 0.73 Variance: 0.0561 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0563
# Saved Epoch 197 as ./checkpoint-houses-bnn-houses-epoch-197.pt
# | Elapsed time : 0:03:22
#
# => Training Epoch #198, LR=0.0008
# | Epoch [198/199] Iter[  9/  9]		Iter Loss: -2.9119, Cumulative Loss: 17.2182
# | Validation Epoch #198			Loss: 44.0483
#
#  | Validation Epoch #198			Confidence Mean: 0.74 Variance: 0.0563 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0563
# Saved Epoch 198 as ./checkpoint-houses-bnn-houses-epoch-198.pt
# | Elapsed time : 0:03:23
#
# => Training Epoch #199, LR=0.0008
# | Epoch [199/199] Iter[  9/  9]		Iter Loss: -2.9665, Cumulative Loss: 26.9605
# | Validation Epoch #199			Loss: 44.1708
#
#  | Validation Epoch #199			Confidence Mean: 0.74 Variance: 0.0565 Epistemic Uncertainty: 0.0000 Aleatoric Uncertainty: 0.0564
# Saved Epoch 199 as ./checkpoint-houses-bnn-houses-epoch-199.pt
# | Elapsed time : 0:03:24
#
#  Test results : Loss = 17.13

# %% [markdown]
# We can see how Training and Validation Loss and Accuracy changes over epochs

# %%
#@title
def plot_loss():
  fig = plt.figure(figsize=(15,6))
  plt.plot(np.arange(len(train_losses)), train_losses, label='Training Loss')
  plt.plot(np.arange(len(val_losses)), val_losses, label='Validation Loss')
  plt.title('Training/Validation Loss for {} on {} across Epochs'.format(net_type, dataset))
  plt.xlabel('Epochs')
  plt.ylabel('Cumulative Loss')
  plt.legend()
  
def plot_acc():
  fig = plt.figure(figsize=(15,6))
  plt.plot(np.arange(len(train_accs)), train_accs, label='Training Accuracy')
  plt.plot(np.arange(len(val_accs)), val_accs, label='Validation Accuracy')
  plt.title('Training/Validation Accuracy for {} on {} across Epochs'.format(net_type, dataset))
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  
plot_loss()
plot_acc()

# %% [markdown]
# For classifications tasks, the variance of the variational approximation to the posterior predictive distribution is estimated by the following formula
#
# $
# \begin{align*}
# Var_{q_\theta(y^*|x^*)}(y^*) &= E_{q_\hat{\theta}(y^*|x^*)}\{y^{*\otimes 2}\} -  E_{q_\hat{\theta}(y^*|x^*)}(y)^{*\otimes 2}\\
# &= \underbrace{\int_\Omega [diag\{E_{p(y^*|x^*, \omega)}(y^*)\} - E_{p(y^*|x^*, \omega)}(y^*)^{\otimes 2}] q_\hat{\theta}(\omega) d\omega}_\text{aleatoric}\\
# &+ \underbrace{\int_\Omega\{E_{p(y^*|x^*, \omega)}(y^*) - E_{q_\hat{\theta}(y^*|x^*)}(y^*)\}^{\otimes 2}q_\hat{\theta}(\omega) d\omega}_\text{epistemic}
# \end{align*}
# $

# %% [markdown]
# The key assumption here is s the replacement of  𝐸𝑝(𝑦∗|𝑥∗,𝜔)(𝑦∗⊗2)  with  𝑑𝑖𝑎𝑔{𝐸𝑝(𝑦∗|𝑥∗,𝜔)(𝑦∗)}  which is valid under the assumption that  𝑦∗  is one-hot encoded, in other words the true label would look like a one-hot encoded vector. This is not true for regression tasks, and hence we can't use the approximation described by [Kwon et. al](https://openreview.net/pdf?id=Sk_P2Q9sG) and Shridar et. al.
#
# However, we can use the original approximation specified by Kendall and Gall [2017] (as described in Kwon et. al). We take the mean and var of output node in addition to the prediction sample, and estimate the predictive variance as:
#
# $
# \begin{align*}
# Var_{q_\theta(y^*|x^*)}(y^*) = \underbrace{\frac{1}{T} \sum_{t=1}^T diag(\hat{\sigma}_t^2)}_\text{aleatoric} + \underbrace{\frac{1}{T} \sum_{t=1}^T (\hat{\mu}_t - \bar{\mu})^{\otimes 2}}_\text{epistemic}
# \end{align*}
# $
#
# where $\bar{\mu} = \sum_{t=1}^T \frac{\hat{\mu}_t}{T}$
#
# The first term is the expected variance in the output i.e. the noise associated with the data. The second term is the variance of the means, i.e. the noise associated with the model predictions.
#
# We can try and see how these values look for a given input image across epochs.

# %% [markdown]
# Lets load all the saved models for different epochs

# %%
def load_states():
  states = []
  for epoch in saved_epochs:
    filename = './checkpoint-{}-{}-epoch-{}.pt'.format(net_type, dataset, epoch)
    state = torch.load(filename)
    states.append(state)
  return states

states = load_states()

# %%
nets = [state['net'] for idx, state in enumerate(states) if idx%1 == 0]
epochs = [state['epoch'] for idx, state in enumerate(states) if  idx%1 == 0]

# %% [markdown]
# Here we try to obtain a sample of predictions for a given input for each epoch.

# %% [markdown]
# This function takes an image and samples it `n_iter` (default 1000) times through model for given epoch.

# %%
def sample_predictive_epoch(feat, epoch, n_iter=100000):
  batch_size = n_iter
  shape = feat.shape
  feat_rep = np.repeat(feat, batch_size, 0).reshape(batch_size, shape[0])
  outs, kl, means, stds = nets[epoch].probforward(feat_rep.cuda(), ret_mean_std=True)
  outputs = outs.detach().cpu().numpy()
  #outputs = normalize(softplus(outs.detach().cpu().numpy()), axis=1, norm='l1')
  mn = means.detach().cpu().numpy()
  vn = stds.detach().cpu().numpy() ** 2
  confidence_mean = np.mean(outputs, axis=0)
  confidence_var = np.var(outputs, axis=0)
  epistemic = np.mean(mn ** 2, axis=0) - np.mean(mn, axis=0) ** 2 #np.mean(p_hat ** 2, axis=0) - np.mean(p_hat, axis=0) ** 2
  aleatoric = np.mean(vn)
  
  return outputs, confidence_mean, confidence_var, epistemic, aleatoric

# %% [markdown]
# The plots are below for a set of features. Its a little wierd to me that there are multiple fairly pronounced modes in the distribution. That tells me the model isn't really learning even though the validation loss went down.
#
# Also, note that for this task the regression label (price) was scaled to be between 0 and 1 (by dividing by the max price).

# %%
def plot_epochs(feat, label, n_iter=100000, start_epoch=10, end_epoch=len(epochs), epoch_inc=20):
  for i in range(start_epoch, end_epoch, epoch_inc):
    outputs, m, v, ep, al = sample_predictive_epoch(feat, i, n_iter)
    fig, ax = plt.subplots(figsize=(15,6))
    sns.distplot(outputs, ax=ax, kde=False, bins=1000, label='Epoch {}'.format(i))
    ax.plot([label, label], [0, 1000], 'r-', linewidth=2, label='Target = {:.4f}'.format(label))
    meanY = np.mean(trainY)
    ax.plot([meanY, meanY], [0, 1000], 'g-', linewidth=2, label='Mean(trainY) = {:.4f}'.format(meanY))
    ax.set_xlim(-0.5, 2.5)
    plt.xticks(np.arange(-0.5, 2.5, 0.25))
    ax.set_ylim(0, 1000)
    plt.legend()
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    fig.suptitle('Sampled Predictive Distribution for Epoch %s. Confidence Mean: %.2f Variance: %.4f Epistemic Uncertainty: %.4f Aleatoric Uncertainty: %.4f'%(i, m, v, ep, al))

# %%
dataloader = iter(testloader)

# %%
features, labels = dataloader.next()

# %%
labels[0].item() #Label Price (Fraction of MaxPrice)
# Out:
# 0.12425000220537186

# %%
plot_epochs(features[0], labels[0].item(), start_epoch=0, end_epoch = 200, epoch_inc=10)

# %%
plot_epochs(features[0], labels[0].item(), start_epoch=0, end_epoch = 200, epoch_inc=10)

# %%
plot_epochs(features[0], labels[0].item(), start_epoch=0, end_epoch = 10, epoch_inc=1)

# %%
labels[10].item() #Label Price (Fraction of MaxPrice)
# Out:
# 0.2745000123977661

# %%
plot_epochs(features[10], labels[10].item(), start_epoch=0, end_epoch = 10, epoch_inc=1)

# %%
labels[25].item() #Label Price (Fraction of MaxPrice)
# Out:
# 0.03849999979138374

# %%
plot_epochs(features[25], labels[25].item(), start_epoch=0, end_epoch = 9, epoch_inc=1)

# %%
#Predictive distribution for outlier
idx = np.where(testY >0.8)[0][0]
xi = torch.Tensor(testX[idx])
yi = torch.Tensor([testY.iloc[idx]])
plot_epochs(xi, yi.item(), start_epoch=0, end_epoch = 30, epoch_inc=3)

# %%
#Training label distribution
fig = plt.figure(figsize=(15,6))
sns.distplot(trainY, kde=False, bins=100)

# %%
#Test label distribution
fig = plt.figure(figsize=(15,6))
sns.distplot(testY, kde=False, bins=100)
