# %% [markdown]
# Train Frequentist CNN models on Strong Lensing Space Set 1 using FastAI.

# %% [markdown]
# ###Google Colab Stuff

# %% [markdown]
# The stuff below is needed to clone a private Github repo from colab

# %%
import os
os.chdir('/content')

from google.colab import files

uploaded = files.upload()

# !ls
# Out:
#      <input type="file" id="files-5138e304-8f8e-47c5-950f-5834e1cdbf16" name="files[]" multiple disabled />
#      <output id="result-5138e304-8f8e-47c5-950f-5834e1cdbf16">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ssh.tar.gz to ssh.tar.gz
# sample_data  ssh.tar.gz

# %%
#Remove the .ssh Folder if it already exists
# !rm -rf /root/.ssh

#Create a new .ssh folder
# !mkdir /root/.ssh

#Unzip the archive file
# !tar xzvf ssh.tar.gz

#Copy the files to /root/.ssh
# !cp ssh-colab/* /root/.ssh && rm -rf ssh-colab && rm -rf ssh.tar.gz
# !chmod 700 /root/.ssh

#Add the git server as a ssh known host
# !touch /root/.ssh/known_hosts
# !ssh-keyscan github.com >> /root/.ssh/known_hosts
# !chmod 644 /root/.ssh/known_hosts
# Out:
# ssh-colab/
# ssh-colab/id_rsa_colab
# ssh-colab/config
# ssh-colab/id_rsa_colab.pub
# # github.com:22 SSH-2.0-babeld-6c2374e6
# # github.com:22 SSH-2.0-babeld-6c2374e6
# # github.com:22 SSH-2.0-babeld-6c2374e6

# %%
#Run the agent, then run `ssh-add /root/.ssh/id_rsa_colab` in the prompt, optionally followed by `ssh-add -l` to verify, finally type `exit`
# !ssh-agent /bin/bash
# Out:
# bash: cannot set terminal process group (141): Inappropriate ioctl for device
# bash: no job control in this shell
# root@e3f87f9e9402:/content# ssh-add /root/.ssh/id_rsa_colab
# Identity added: /root/.ssh/id_rsa_colab (pankajb64@gmail.com)
# root@e3f87f9e9402:/content# exit
# exit

# %% [markdown]
# You'll need to set this to your github username and email.

# %%
# !git config --global user.email "pankajb64@gmail.com"
# !git config --global user.name "pankajb64"

# %%
# !git clone git@github.com:deepskies/stronglensbnns.git
# Out:
# Cloning into 'stronglensbnns'...
# Warning: Permanently added the RSA host key for IP address '192.30.253.113' to the list of known hosts.
# remote: Enumerating objects: 409, done.
# remote: Counting objects: 100% (409/409), done.
# remote: Compressing objects: 100% (245/245), done.
# remote: Total 409 (delta 164), reused 390 (delta 145), pack-reused 0
# Receiving objects: 100% (409/409), 7.00 MiB | 32.01 MiB/s, done.
# Resolving deltas: 100% (164/164), done.

# %%
# !cd stronglensbnns/ && git pull
# Out:
# Already up to date.

# %% [markdown]
# ### Download dataset

# %% [markdown]
# Need permissions to store data onto drive.

# %%
from google.colab import auth
auth.authenticate_user()

# %%
# !gsutil  -m cp  gs://strong_lens_challenge/Space_set_1/SpaceBasedChallenge.1.tar.gz stronglensbnns/data/
# Out:
# Copying gs://strong_lens_challenge/Space_set_1/SpaceBasedChallenge.1.tar.gz...
# \ [1/1 files][  3.6 GiB/  3.6 GiB] 100% Done  70.8 MiB/s ETA 00:00:00
# Operation completed over 1 objects/3.6 GiB.

# %%
# !gsutil cp gs://strong_lens_challenge/Space_set_1/euclidB_image_catalog.csv stronglensbnns/data/
# Out:
# Copying gs://strong_lens_challenge/Space_set_1/euclidB_image_catalog.csv...
# / [1 files][ 11.1 MiB/ 11.1 MiB]
# Operation completed over 1 objects/11.1 MiB.

# %%
# !cd stronglensbnns/data && tar xf SpaceBasedChallenge.1.tar.gz && rm -rf SpaceBasedChallenge.1.tar.gz

# %%
# !cd stronglensbnns/data && mkdir -p Space_set_1 && mv Data_* Space_set_1 && rm README

# %%
# !cd stronglensbnns/data && ls
# Out:
# bayesiancnn  ensai  euclidB_image_catalog.csv  Space_set_1

# %% [markdown]
# ### Begin Notebook

# %%
from fastai.vision import *
from pathlib import Path
from astropy.io import fits
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from PIL import Image

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import torch.nn as nn

import os

# %%
#add the  bayesiancnnn and ensai src to import path - https://stackoverflow.com/a/35273613/7154530
bcnn_module_path = os.path.abspath(os.path.join('stronglensbnns/src/bayesiancnn'))
if bcnn_module_path not in sys.path:
    sys.path.append(bcnn_module_path)
    
ensai_module_path = os.path.abspath(os.path.join('stronglensbnns/src/ensai'))
if ensai_module_path not in sys.path:
    sys.path.append(ensai_module_path)

# %% [markdown]
# We consider instances where `numb_pix_lensed_image` is between 100 and 500 as valid. We also use scaled log of einstein area as our label.

# %%
df = pd.read_csv('../../data/euclidB_image_catalog.csv', skiprows=24)
df_lens = df.loc[(df['numb_pix_lensed_image'] > 100) & (df['numb_pix_lensed_image'] < 500)]
df_lens['scaled_log_ein_area'] = np.log(df_lens['Einstein_area']) + np.log(2e10)
df_lens['scaled_ein_area'] = df_lens['Einstein_area']*1e9
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# Convert FITS images to JPG to alow FastAI to process them.

# %%
dirs = ['../../data/Space_set_1/{}'.format(d) for d in os.listdir('../../data/Space_set_1/') if 'Data' in d]

# %%
files = []
for d in dirs:
    fits_dir = '{}/Public/Band1'.format(d)
    jpg_dir = '{}/Public_jpg/Band1'.format(d)
    #os.makedirs(jpg_dir, exist_ok=True)
    for f in os.listdir(fits_dir):
        fname = fits_dir + '/' + f
        #ar = fits.open(fname)[0].data
        id = int(fname.split('-')[1].split('.')[0])
        fj = '{}/{}.jpg'.format(jpg_dir, id)
        #plt.imsave(fj, ar)
        files.append(fj)

# %%
df_files = pd.DataFrame()
df_files['fname'] = files
df_files['ID'] = [int(os.path.splitext(os.path.basename(fname))[0]) for fname in files]

df_merge = pd.merge(df_lens, df_files, on='ID')

# %%
df_merge.head()
# Out:
#        ID    x_crit    y_crit  ID_source  z_source  EUC_VIS_mag_source  \
# 0  186193 -0.004088  0.007850       4361      2.42              26.691
# 1  116891 -0.001330  0.005507       3068      1.38              26.094
# 2  110511 -0.001330  0.005507       1738      2.57              26.298
# 3  113377 -0.001634 -0.000123       1626      1.38              25.601
# 4  126021 -0.001634 -0.000123       6151      1.04              26.914
#
#    caustic_plane  caustic_index  z_caustic_plane  Einstein_area  ...  \
# 0              8          45369              1.5   1.814210e-09  ...
# 1              8          38977              1.5   1.577840e-10  ...
# 2              8          38977              1.5   1.195500e-09  ...
# 3              8          21112              1.5   1.270680e-10  ...
# 4              8          21112              1.5   4.869460e-11  ...
#
#    total_numb_pixels_sigma  flux_in_sigma  num_images  EUC_VIS_mag_lens  \
# 0                     9047       219315.0          14           17.2585
# 1                     3190        14748.9         541           20.7723
# 2                     3523        14728.4         532           20.7233
# 3                     5222        23615.8         267           19.9194
# 4                     5295        25373.6         287           19.8887
#
#    kids_lens_image  mobs_lens_imag  no_source  scaled_log_ein_area  \
# 0                0               1          0             3.591382
# 1                0               1          0             1.149204
# 2                0               1          0             3.174297
# 3                0               1          0             0.932699
# 4                0               1          0            -0.026455
#
#    scaled_ein_area                                              fname
# 0         1.814210  ../../data/Space_set_1/Data_EuclidBig.0/Public...
# 1         0.157784  ../../data/Space_set_1/Data_EuclidBig.0/Public...
# 2         1.195500  ../../data/Space_set_1/Data_EuclidBig.0/Public...
# 3         0.127068  ../../data/Space_set_1/Data_EuclidBig.0/Public...
# 4         0.048695  ../../data/Space_set_1/Data_EuclidBig.0/Public...
#
# [5 rows x 25 columns]

# %% [markdown]
# Create a `DataBunch` - a way to access training and validation set in FastAI. Transform it using standard image processing transforms - rotate, zoom, flip, etc. Resize the image to be 224x224 (needed for resnets)
#
# **Normalize the image using Imagenet stats - this is important since the model is pre-trained on Imagenet.**

# %%
data = (ImageList
.from_df(path='', df=df_merge, cols='fname')
.split_by_rand_pct(seed=42)
.label_from_df(cols='scaled_log_ein_area',label_cls=FloatList)
.transform(get_transforms(), size=(224,224))
.databunch()
.normalize(imagenet_stats))

# %% [markdown]
# FastAI allows us to easily visualize a batch of training data and corresponding labels.

# %%
data.show_batch()

# %% [markdown]
# The way to train in FastAI is to create a learner object - here we create a `cnn_learner` which takes in a `DataBunch` (created above), a base model (Resnet18 in our case), metrics and any callbacks. `ShowGraph` is a useful callback that allows us to visualize the loss and any metrics evaluated during training and validation.

# %%
learn = cnn_learner(data, models.alexnet, callback_fns=ShowGraph)

# %% [markdown]
# A really cool feature of FastAI is the learning rate finder, it tries out a bunch learning rates within a range (typically 1e-7 to 10) for a few iterations each and plots the loss as a function of learning rate.

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# The creators of FastAI advise that we pick the learning rate corresponding to the steepest part of the curve. Its hard to know in the above case, I pick 5e-4
#
# We can train by calling `learn.fit_one_cycle` - which fits the data, but for each epoch it varies the learning rate (from low to high and back to low). This is reported as giving better performance by FastAI creators. See https://sgugger.github.io/the-1cycle-policy.html for more details.

# %%
#@title
lr = 5e-4
learn.fit_one_cycle(10, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.935983</td>
#       <td>3.312740</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.308092</td>
#       <td>2.791546</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.443350</td>
#       <td>2.416884</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.948819</td>
#       <td>2.373312</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.650152</td>
#       <td>2.343682</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.527521</td>
#       <td>2.293553</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.472215</td>
#       <td>2.226443</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.467870</td>
#       <td>2.237796</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.376180</td>
#       <td>2.233191</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.438507</td>
#       <td>2.242977</td>
#       <td>00:30</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The above model was trained with the weights of the base model being "frozen" - they were not updated during the training. We may wanna train the entire model to fine-tune the performance.
#
# For this we can "unfreeze" the model and tune all the weights.

# %%
learn.unfreeze()

# %% [markdown]
# It is recommended the pre-trained weights (the top layers) be trained with a much smaller learning rates and they're mostly well trained. The bottom layers can be trained with a higher learning rate. FastAI allows us to specify differential learning rate - with the minimum learning rate applied to the top layer, the maximum applied to the bottom layers, and intermediate values applied to the layers in between.

# %%
learn.fit_one_cycle(10, slice(1e-6, 5e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.396383</td>
#       <td>2.145731</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.214076</td>
#       <td>1.986435</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.079015</td>
#       <td>1.848100</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.956784</td>
#       <td>1.806279</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.854915</td>
#       <td>1.712091</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.772765</td>
#       <td>1.676412</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.729526</td>
#       <td>1.595096</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.712685</td>
#       <td>1.576493</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.617608</td>
#       <td>1.554775</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.607888</td>
#       <td>1.557215</td>
#       <td>00:32</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(10, slice(1e-6, 5e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.663646</td>
#       <td>1.549247</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.707620</td>
#       <td>1.541832</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.642226</td>
#       <td>1.570690</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.654756</td>
#       <td>1.567757</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.631541</td>
#       <td>1.509686</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.517774</td>
#       <td>1.495694</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.518868</td>
#       <td>1.445812</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.495484</td>
#       <td>1.432483</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.432578</td>
#       <td>1.414169</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.418442</td>
#       <td>1.418461</td>
#       <td>00:31</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(5, slice(1e-6, 5e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.512765</td>
#       <td>1.488735</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.524768</td>
#       <td>1.429861</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.434669</td>
#       <td>1.413546</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.447130</td>
#       <td>1.404089</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.405245</td>
#       <td>1.369306</td>
#       <td>00:30</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# It is also easy to view the model predictions on a validation set.

# %%
learn.show_results()

# %% [markdown]
# We can use the predictions to plot a scatter plot of ground truth vs predictions using the approach in the previous notebooks

# %%
trainset = data.train_ds
testset = data.valid_ds
trainloader = data.train_dl
testloader = data.valid_dl

# %%
target_sum = 0.0
target_count = 0
for _, targets in trainloader:
    print(targets.shape)
    target_sum += targets.detach().cpu().numpy().squeeze().sum()
    target_count += targets.shape[0]
train_mean = target_sum/target_count
# Out:
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])

# %%
def scatter_plots_f():
    preds, labs = learn.get_preds()
    print(preds.shape)
    print(labs.shape)
    #print(preds)
    #print(labs)
    #pt = torch.from_numpy(preds)
    #pl = torch.from_numpy(labs)
    #loss = criterion(pt, pl)
    #print('Loss: {}'.format(loss))
    #print(testY)
    fig, ax = plt.subplots(figsize=(15,6))
    points = [[-4, 4]]
    trainY_mean = train_mean
    lr = LinearRegression()
    lr.fit(labs.reshape(-1, 1), preds)
    pp = lr.predict(labs.reshape(-1, 1))  
    for j in range(1):
        sns.scatterplot(x=labs, y=preds.squeeze(), ax=ax)
        ax.plot(points[j], points[j], '--r', label='ideal relationship line')
        ax.plot(points[j], [trainY_mean, trainY_mean], '--g', label='line if predicting train mean')
        ax.plot(labs, pp, '--b', label='current relationship line')
        ax.set_xlabel('Einstein Area : true')
        ax.set_ylabel('Einstein Area : predicted')
        ax.set_xlim(points[j])
        ax.set_ylim(points[j])
        ax.legend()
    fig.suptitle('Scatter plots for true vs predicted values for the parameters')
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# %%
scatter_plots_f()
# Out:
# torch.Size([3730, 1])
# torch.Size([3730])
