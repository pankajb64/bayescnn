# %% [markdown]
# ##Google Colab Stuff

# %%
import os
os.chdir('/content')

from google.colab import files

uploaded = files.upload()

# !ls
# Out:
#      <input type="file" id="files-4fefe0ba-6fac-496e-bc53-9ef69f926165" name="files[]" multiple disabled />
#      <output id="result-4fefe0ba-6fac-496e-bc53-9ef69f926165">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ssh.tar.gz to ssh.tar.gz
# sample_data  ssh.tar.gz

# %%
#Remove the .ssh Folder if it already exists
# !rm -rf /root/.ssh

#Create a new .ssh folder
# !mkdir /root/.ssh

#Unzip the archive file
# !tar xzvf ssh.tar.gz

#Copy the files to /root/.ssh
# !cp ssh-colab/* /root/.ssh && rm -rf ssh-colab && rm -rf ssh.tar.gz
# !chmod 700 /root/.ssh

#Add the git server as a ssh known host
# !touch /root/.ssh/known_hosts
# !ssh-keyscan github.com >> /root/.ssh/known_hosts
# !chmod 644 /root/.ssh/known_hosts
# Out:
# ssh-colab/
# ssh-colab/id_rsa_colab
# ssh-colab/config
# ssh-colab/id_rsa_colab.pub
# # github.com:22 SSH-2.0-babeld-6c2374e6
# # github.com:22 SSH-2.0-babeld-6c2374e6
# # github.com:22 SSH-2.0-babeld-6c2374e6

# %%
#Run the agent, then run `ssh-add /root/.ssh/id_rsa_colab` in the prompt, optionally followed by `ssh-add -l` to verify, finally type `exit`
# !ssh-agent /bin/bash
# Out:
# bash: cannot set terminal process group (125): Inappropriate ioctl for device
# bash: no job control in this shell
# root@45e18bfd0981:/content# ssh-add /root/.ssh/id_rsa_colab
# Identity added: /root/.ssh/id_rsa_colab (pankajb64@gmail.com)
# root@45e18bfd0981:/content# exit
# exit

# %%
# !git config --global user.email "pankajb64@gmail.com"
# !git config --global user.name "pankajb64"

# %%
# !git clone git@github.com:deepskies/stronglensbnns.git
# Out:
# Cloning into 'stronglensbnns'...
# Warning: Permanently added the RSA host key for IP address '140.82.118.4' to the list of known hosts.
# remote: Enumerating objects: 409, done.
# remote: Counting objects: 100% (409/409), done.
# remote: Compressing objects: 100% (245/245), done.
# remote: Total 409 (delta 164), reused 390 (delta 145), pack-reused 0
# Receiving objects: 100% (409/409), 7.00 MiB | 8.75 MiB/s, done.
# Resolving deltas: 100% (164/164), done.

# %%
from google.colab import auth
auth.authenticate_user()

# %% [markdown]
# ##Download dataset

# %%
import os
os.chdir('../../../')

# %%
# !gsutil  -m cp  gs://strong_lens_challenge/Space_set_1/SpaceBasedChallenge.1.tar.gz stronglensbnns/data/
# Out:
# AccessDeniedException: 403 153565827631-compute@developer.gserviceaccount.com does not have storage.objects.list access to strong_lens_challenge.
# CommandException: 1 file/object could not be transferred.

# %%
# !gsutil cp gs://strong_lens_challenge/Space_set_1/euclidB_image_catalog.csv stronglensbnns/data/
# Out:
# Copying gs://strong_lens_challenge/Space_set_1/euclidB_image_catalog.csv...
# / [1 files][ 11.1 MiB/ 11.1 MiB]
# Operation completed over 1 objects/11.1 MiB.

# %%
# !cd stronglensbnns/data && tar xf SpaceBasedChallenge.1.tar.gz && rm -rf SpaceBasedChallenge.1.tar.gz && ls
# Out:
# bayesiancnn	  Data_EuclidBig.3  Data_EuclidBig.7  euclidB_image_catalog.csv
# Data_EuclidBig.0  Data_EuclidBig.4  Data_EuclidBig.8  README
# Data_EuclidBig.1  Data_EuclidBig.5  Data_EuclidBig.9
# Data_EuclidBig.2  Data_EuclidBig.6  ensai

# %%
# !cd stronglensbnns/data && mkdir -p Space_set_1 && mv Data_* Space_set_1 && rm README && ls
# Out:
# bayesiancnn  ensai  euclidB_image_catalog.csv  Space_set_1

# %% [markdown]
# ##Begin Notebook

# %%
#@title
from __future__ import print_function

import os
import sys
import time
import argparse
import datetime
import math
import pickle
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import torchvision
import torchvision.transforms as transforms
import torchvision.transforms.functional as TF

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
from torch.autograd import Variable

from astropy.io import fits
from fastai.vision import *
#from scipy.special import softmax
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#os.chdir('stronglensbnns/src/notebooks')

# %%
#!git pull

# %%
#add the  bayesiancnnn and ensai src to import path - https://stackoverflow.com/a/35273613/7154530
bcnn_module_path = os.path.abspath(os.path.join('../bayesiancnn'))
if bcnn_module_path not in sys.path:
    sys.path.append(bcnn_module_path)
    
ensai_module_path = os.path.abspath(os.path.join('../ensai'))
if ensai_module_path not in sys.path:
    sys.path.append(ensai_module_path)

# %%
from BBBlayers import GaussianVariationalInference, FlattenLayer, BBBLinearFactorial
from BayesianModels.BayesianAlexNet import BBBAlexNet
from BayesianModels.BayesianAlexNetBatchNorm import BBBAlexNetBatchNorm

# %%
df = pd.read_csv('../../data/euclidB_image_catalog.csv', skiprows=24)

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.boxplot(x=df['no_source'], y=df['numb_pix_lensed_image'], showfliers=False, ax=ax)

# %% [markdown]
# If the instance is a source (i.e `no_source = 0`), then we can a distribution of lensed image pixels with first and third quartile being around 100 and 500. So lets use these instances for training.

# %%
df_lens = df.loc[(df['numb_pix_lensed_image'] > 100) & (df['numb_pix_lensed_image'] < 500)]

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.distplot(df_lens['Einstein_area'], bins=1000, ax=ax, kde=False)
ax.set_xlim(0, 0.2e-9)
# Out:
# (0, 2e-10)

# %% [markdown]
# It may help to scale the values to avoid running into floating point errors, and also to take the log of the distribution since the above curve is exponential. I found that scaling values by 2e10 and taking log gave a nice symmetric range for distribution

# %%
df_lens['scaled_log_ein_area'] = np.log(df_lens['Einstein_area']) + np.log(2e10)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.distplot(df_lens['scaled_log_ein_area'], bins=100, ax=ax, kde=False)
#ax.set_xlim(0, 0.2)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
fig, ax = plt.subplots(figsize=(15,6))
sns.scatterplot(df_lens['numb_pix_lensed_image'], df_lens['scaled_log_ein_area'], ax=ax)

# %% [markdown]
# So the Einstein area and the number of lensed are uncorrelated, and were likely chosen independently in the simulation.

# %% [markdown]
# Convert FITS images to JPG to alow FastAI to process them.

# %%
dirs = ['../../data/Space_set_1/{}'.format(d) for d in os.listdir('../../data/Space_set_1/') if 'Data' in d]

# %%
files = []
for d in dirs:
    fits_dir = '{}/Public/Band1'.format(d)
    jpg_dir = '{}/Public_jpg/Band1'.format(d)
    #os.makedirs(jpg_dir, exist_ok=True)
    for f in os.listdir(fits_dir):
        fname = fits_dir + '/' + f
        #ar = fits.open(fname)[0].data
        id = int(fname.split('-')[1].split('.')[0])
        fj = '{}/{}.jpg'.format(jpg_dir, id)
        #plt.imsave(fj, ar)
        files.append(fj)

# %%
df_files = pd.DataFrame()
df_files['fname'] = files
df_files['ID'] = [int(os.path.splitext(os.path.basename(fname))[0]) for fname in files]

# %%
df_merge = pd.merge(df_lens, df_files, on='ID')

# %%
#@title
#net_type = 'houses-bnn'
#dataset = 'houses'
net_type = 'alexnet'
dataset = 'stronglens-challenge'
numpix_side = 101
outputs = 1
inputs = 3
regression = True
resume = False
start_epoch = 0
n_epochs = 10 #set to 10 for MNIST, 30 for cifar10, and 200 for house pricing
lr = 1e-3
weight_decay = 1e-4
num_samples = 10
beta_type = "Blundell"
resize=224
optim_type = 'Adam'
best_acc = 0
best_loss = np.inf
# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 16
# percentage of training set to use as validation
valid_size = 0.1
#load every nth saved epoch (change to a smaller number for classification problems where num_epochs is less)
load_multiple = 1 #set to 25 (or 10) for house pricing, 1 for MNIST, 3 for cifar10
classes = ['einsten_area']
output_names = ['Einstein Area'] #['Einstein Radius', 'Ellipticity (x)', 'Ellipticity (y)', 'Center (x)', 'Center (y)']
num_channels = 3

# %% [markdown]
# Create a `DataBunch` - a way to access training and validation set in FastAI. Transform it using standard image processing transforms - rotate, zoom, flip, etc. Resize the image to be 224x224 (needed for resnets)
#
# **Normalize the image using Imagenet stats - this is important since the model is pre-trained on Imagenet.**

# %%
data = (ImageList
.from_df(path='', df=df_merge, cols='fname')
.split_by_rand_pct(seed=42)
.label_from_df(cols='scaled_log_ein_area',label_cls=FloatList)
.transform(get_transforms(), size=(resize,resize))
.databunch(bs=batch_size)
.normalize(imagenet_stats))

# %% [markdown]
# Get the Training and Test Dataset and Data Loader

# %%
trainset = data.train_ds
testset = data.valid_ds
trainloader = data.train_dl
testloader = data.valid_dl

# %%
# Hyper Parameter settings
use_cuda = torch.cuda.is_available()
if use_cuda is True:
    torch.cuda.set_device(0)

# %%
from fastai.vision import *
from fastai.vision.learner import num_features_model
#model = create_bnn_model(resnet18, outputs)

# %% [markdown]
# This class loads a pre-trained Frequentist model and adds Bayesian linear layers to it.

# %%
class BayesianPreTrainedModel(nn.Module):
  def __init__(self, body, outputs, freeze_base=True):
    super(BayesianPreTrainedModel, self).__init__()
    self.base_model = body
    if freeze_base:
      for param in self.base_model.parameters():
        param.requires_grad = False
    nf = num_features_model(nn.Sequential(*self.base_model.children())) * 2
    lin_ftrs = [nf, 512, outputs]
    self.pool1 = AdaptiveConcatPool2d()
    self.flatten = Flatten()
    self.linear1 = BBBLinearFactorial(nf, 512)
    self.actn1 = nn.ReLU(inplace=True)
    self.bn1 = nn.BatchNorm1d(512, momentum=0.01)
    self.linear2 = BBBLinearFactorial(512, outputs)

    self.layers = [self.base_model, self.pool1, self.flatten, self.linear1, self.actn1, self.bn1, self.linear2]

  def unfreeze(self):
      for param in self.base_model.parameters():
        param.requires_grad = True

  def freeze(self):
    for param in self.base_model.parameters():
        param.requires_grad = True

  def probforward(self, x, ret_mean_std=False):
    'Forward pass with Bayesian weights'
    kl = 0
    fc_qw_mean = 0
    fc_qw_std = 0
    
    #import pdb; pdb.set_trace()

    for layer in self.layers:
        if hasattr(layer, 'convprobforward') and callable(layer.convprobforward):
            x, _kl, = layer.convprobforward(x)
            kl += _kl

        elif hasattr(layer, 'fcprobforward') and callable(layer.fcprobforward):
            if ret_mean_std:
                x, _kl, fc_qw_mean, fc_qw_std = layer.fcprobforward(x, True)
                kl += _kl
            else:
                #print(layer)
                x, _kl = layer.fcprobforward(x, ret_mean_std=False)
                kl += _kl    
        else:
            x = layer(x)
    logits = x
    #print('logits', logits)

    if not ret_mean_std:
        return logits, kl
    else:
        return logits, kl, fc_qw_mean, fc_qw_std

# %% [markdown]
# Create a Bayesian Pre-Trained model using Resnet 18

# %%
body = create_body(models.resnet18, pretrained=True, cut=None)
net = BayesianPreTrainedModel(body, outputs)
#net = BBBAlexNetBatchNorm(outputs,inputs)
if use_cuda:
    net.cuda()

loss = torch.nn.MSELoss()
vi = GaussianVariationalInference(loss, log=True)

#summary(net, input_size=(inputs, numpix_side, numpix_side))

#logfile = os.path.join('diagnostics_Bayes{}_{}.txt'.format(net_type, dataset))

# %% [markdown]
# Helper functions for printing and varying parameters

# %%
#Pretty print estimates
def pp_estimates(names, confidence_mean, confidence_var, epistemic, aleatoric, tag='Parameter'):
    print('\n\n----------------------------------------------------------------------------------------------\n')
    print(    '|{:>15s}| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |\n'.format(tag))
    print(    '----------------------------------------------------------------------------------------------\n')
    for i in range(len(names)):
        print('|{:>15s}|{:>17.4f}|{:>10.4f}|{:>23.4f}|{:>23.4f}|\n'.format(names[i], confidence_mean[i], confidence_var[i], epistemic[i], aleatoric[i]))
    print(    '----------------------------------------------------------------------------------------------\n\n')

# %%
def learning_rate(init, epoch):
    optim_factor = 0
    if(epoch > 60):
        optim_factor = 3
    elif(epoch > 70):
        optim_factor = 2
    elif(epoch > 80):
        optim_factor = 1

    return init*math.pow(0.2, optim_factor)

def get_hms(seconds):
    m, s = divmod(seconds, 60)
    h, m = divmod(m, 60)

    return h, m, s

# %% [markdown]
# Functions to train and test for an epoch

# %%
#@title
def train(epoch, write=False):
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    m = math.ceil(len(trainset) / batch_size)
    optimizer = optim.Adam(net.parameters(), lr=learning_rate(lr, epoch), weight_decay=weight_decay)

    if write:
      print('\n=> Training Epoch #%d, LR=%.4f' %(epoch, learning_rate(lr, epoch)))
    for batch_idx, (inputs_value, targets) in enumerate(trainloader): 
        x = inputs_value.view(-1, inputs, resize, resize).repeat(num_samples, 1, 1, 1)
        #x_nobias = remove_image_intensity_bias(x)
        #x = x_nobias.repeat(1, 1, 1, 1)
        y = targets.view(-1, outputs).repeat(num_samples, 1)
        if use_cuda:
            x, y = x.cuda(), y.cuda() # GPU settings

        if beta_type is "Blundell":
            beta = 2 ** (m - (batch_idx + 1)) / (2 ** m - 1)
        elif beta_type is "Soenderby":
            beta = min(epoch / (num_epochs // 4), 1)
        elif beta_type is "Standard":
            beta = 1 / m
        else:
            beta = 0
        # Forward Propagation
        x, y = Variable(x), Variable(y)
        outs, kl = net.probforward(x)
        #print(inputs_value.shape, targets.shape)
        #print(x.shape, y.shape, outs.shape)
        #print(outs)
        #print(y)
        loss = vi(outs, y, kl, beta)  # Loss
        optimizer.zero_grad()
        loss.backward()  # Backward Propagation
        optimizer.step()  # Optimizer update

        train_loss += loss.data.item()
        loss = loss.data.item()
        if write:
          sys.stdout.write('\r')
          sys.stdout.write('| Epoch [%3d/%3d] Iter[%3d/%3d]\t\tIter Loss: %.4f, Cumulative Loss: %.4f' %(epoch, n_epochs-1, batch_idx+1,
                (len(trainset)//batch_size)+1, loss, train_loss))
          sys.stdout.flush()
    
    return train_loss

# %%
#@title 
def test(epoch, save_epoch=False):
    global best_acc, best_loss
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    predictions=[]
    means = []
    variances = []
    epistemics = []
    aleatorics = []
    m = math.ceil(len(testset) / batch_size)
    for batch_idx, (inputs_value, targets) in enumerate(testloader):
        x = inputs_value.view(-1, inputs, resize, resize).repeat(num_samples, 1, 1, 1)
        #x_nobias = remove_image_intensity_bias(x)
        #x = x_nobias.repeat(1, 1, 1, 1)
        y = targets.view(-1, outputs).repeat(num_samples, 1)
        if use_cuda:
            x, y = x.cuda(), y.cuda()
        with torch.no_grad():
            x, y = Variable(x), Variable(y)
        outs, kl, mus, sigmas = net.probforward(x, ret_mean_std=True)
        #print(mns)
        if beta_type is "Blundell":
            beta = 2 ** (m - (batch_idx + 1)) / (2 ** m - 1)
        elif beta_type is "Soenderby":
            beta = min(epoch / (num_epochs // 4), 1)
        elif beta_type is "Standard":
            beta = 1 / m
        else:
            beta = 0

        loss = vi(outs, y, kl, beta)

        test_loss += loss.data.item()
        loss = loss.data.item()
        preds = outs
        results = preds.cpu().detach().numpy() #.data.mean(dim=0) #torch.topk(preds.cpu().data, k=1, dim=0)
        confidence_mean = np.mean(results, axis=0)
        confidence_var = np.var(results, axis=0)
        mus = mus.cpu().detach().numpy()
        sigmas = sigmas.cpu().detach().numpy() ** 2 
        epistemic = np.mean(mus ** 2, axis=0) - np.mean(mus, axis=0) ** 2
        aleatoric = np.mean(sigmas, axis=0)
        
        means.append(confidence_mean)  
        variances.append(confidence_var)
        epistemics.append(epistemic)
        aleatorics.append(aleatoric)

    # Save checkpoint when best model
    confidence_mean = np.mean(means, axis=0)
    confidence_var = np.mean(variances, axis=0)
    epistemic = np.mean(epistemics, axis=0)
    aleatoric = np.mean(aleatorics, axis=0)
    #print(confidence_mean, confidence_var, epistemic, aleatoric)
    print('\n| Validation Epoch #%d'%(epoch))
    pp_estimates(output_names, confidence_mean, confidence_var, epistemic, aleatoric)
    state = {
        'net':net,
        'epoch':epoch,
        'loss': test_loss,
        }
    
    if save_epoch:
       if not os.path.isdir('checkpoint'):
            os.mkdir('checkpoint')
       
       save_point = './checkpoint/checkpoint-{}-{}-epoch-{}.pt'.format(net_type, dataset, epoch)
       torch.save(state, save_point)
       print('Saved Epoch {} as {}'.format(epoch, save_point))
      
    if test_loss < best_loss:
        print('| Saving Best model...\t\t\tLoss = %.2f' %(test_loss))
        best_loss = test_loss
        
        if not os.path.isdir('checkpoint'):
            os.mkdir('checkpoint')
        save_point = './checkpoint/'+dataset+os.sep
        ckpt_name = f'model_{net_type}_{dataset}_bayesian.pt'
        if not os.path.isdir(save_point):
            os.mkdir(save_point)
        torch.save(state, save_point+ckpt_name)
    
    return test_loss

# %%
def run():
  #@title
  elapsed_time = 0
  saved_epochs = []

  train_losses = []
  train_accs = []

  val_losses = []
  val_accs = []

  for epoch in range(start_epoch, start_epoch+n_epochs):
      start_time = time.time()
      nthEpoch = True #((epoch < 100) and (epoch% 10 == 0)) or ( (epoch < 1000) and (epoch%100 == 0)) or (epoch%500 == 0)
      tloss = train(epoch, nthEpoch)
      train_losses.append(tloss)
      if nthEpoch:
          vloss = test(epoch, save_epoch = True )
          val_losses.append(vloss)
          saved_epochs.append(epoch)
      
      epoch_time = time.time() - start_time
      elapsed_time += epoch_time
      if nthEpoch:
        print('| Elapsed time : %d:%02d:%02d' %(get_hms(elapsed_time)))

  print('\n Test results : Loss = %.2f' %(best_loss))
  return (saved_epochs, train_losses, val_losses)

# %% [markdown]
# Run the model for set number of epochs (defined by `n_epochs` field). Saves the model at each epoch.

# %%
(saved_epochs, train_losses, val_losses) = run()
# Out:
# => Training Epoch #0, LR=0.0010
# | Epoch [  0/  9] Iter[932/933]		Iter Loss: 1.0997, Cumulative Loss: 469663.703333649
# | Validation Epoch #0
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.9462|    0.8638|                 1.0559|                 0.3425|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 0 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-0.pt
# | Saving Best model...			Loss = 442642.82
# /opt/anaconda3/lib/python3.7/site-packages/torch/serialization.py:256: UserWarning: Couldn't retrieve source code for container of type BayesianPreTrainedModel. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# | Elapsed time : 0:01:36
#
# => Training Epoch #1, LR=0.0010
# | Epoch [  1/  9] Iter[932/933]		Iter Loss: 1.3033, Cumulative Loss: 441488.803583919
# | Validation Epoch #1
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -1.4088|   17.1661|                16.0121|                 5.6525|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 1 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-1.pt
# | Saving Best model...			Loss = 416094.54
# | Elapsed time : 0:03:11
#
# => Training Epoch #2, LR=0.0010
# | Epoch [  2/  9] Iter[932/933]		Iter Loss: 1.1811, Cumulative Loss: 414902.606443706
# | Validation Epoch #2
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          26.6297|  172.5350|                12.3057|               161.2126|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 2 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-2.pt
# | Saving Best model...			Loss = 392637.90
# | Elapsed time : 0:04:46
#
# => Training Epoch #3, LR=0.0010
# | Epoch [  3/  9] Iter[932/933]		Iter Loss: 0.7400, Cumulative Loss: 389730.861995875
# | Validation Epoch #3
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.7654|    0.8715|                 0.8617|                 0.0093|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 3 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-3.pt
# | Saving Best model...			Loss = 366872.48
# | Elapsed time : 0:06:21
#
# => Training Epoch #4, LR=0.0010
# | Epoch [  4/  9] Iter[932/933]		Iter Loss: 1.1557, Cumulative Loss: 366014.725279174
# | Validation Epoch #4
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.3419|    0.9574|                 0.9508|                 0.0062|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 4 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-4.pt
# | Saving Best model...			Loss = 343471.34
# | Elapsed time : 0:07:57
#
# => Training Epoch #5, LR=0.0010
# | Epoch [  5/  9] Iter[932/933]		Iter Loss: 1.1269, Cumulative Loss: 343104.306628252
# | Validation Epoch #5
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.9032|    0.9589|                 0.9528|                 0.0049|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 5 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-5.pt
# | Saving Best model...			Loss = 321592.95
# | Elapsed time : 0:09:32
#
# => Training Epoch #6, LR=0.0010
# | Epoch [  6/  9] Iter[932/933]		Iter Loss: 1.4753, Cumulative Loss: 320913.002908368
# | Validation Epoch #6
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -1.0786|    0.9467|                 0.9420|                 0.0048|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 6 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-6.pt
# | Saving Best model...			Loss = 300341.19
# | Elapsed time : 0:11:07
#
# => Training Epoch #7, LR=0.0010
# | Epoch [  7/  9] Iter[932/933]		Iter Loss: 1.1267, Cumulative Loss: 300073.024162511
# | Validation Epoch #7
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.7219|    0.9491|                 0.9456|                 0.0036|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 7 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-7.pt
# | Saving Best model...			Loss = 280170.89
# | Elapsed time : 0:12:42
#
# => Training Epoch #8, LR=0.0010
# | Epoch [  8/  9] Iter[932/933]		Iter Loss: 1.4910, Cumulative Loss: 280557.617496524
# | Validation Epoch #8
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.7211|    1.1489|                 1.1447|                 0.0039|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 8 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-8.pt
# | Saving Best model...			Loss = 261310.54
# | Elapsed time : 0:14:16
#
# => Training Epoch #9, LR=0.0010
# | Epoch [  9/  9] Iter[932/933]		Iter Loss: 0.7678, Cumulative Loss: 261293.247571941
# | Validation Epoch #9
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.2352|    1.0565|                 1.0534|                 0.0034|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 9 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-9.pt
# | Saving Best model...			Loss = 243206.08
# | Elapsed time : 0:15:51
#
#  Test results : Loss = 243206.08

# %% [markdown]
# Plot the loss function across epochs

# %%
#@title
def plot_loss():
  fig = plt.figure(figsize=(15,6))
  plt.plot(np.arange(len(train_losses)), train_losses, label='Training Loss')
  plt.plot(np.arange(len(val_losses)), val_losses, label='Validation Loss')
  plt.title('Training/Validation Loss for {} on {} across Epochs'.format(net_type, dataset))
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  
def plot_acc():
  fig = plt.figure(figsize=(15,6))
  plt.plot(np.arange(len(train_accs)), train_accs, label='Training Accuracy')
  plt.plot(np.arange(len(val_accs)), val_accs, label='Validation Accuracy')
  plt.title('Training/Validation Accuracy for {} on {} across Epochs'.format(net_type, dataset))
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()

# %%
plot_loss()
#plot_acc()

# %% [markdown]
# Load the model saved at each epoch.

# %%
#@title
def plot_loss():
  fig = plt.figure(figsize=(15,6))
  plt.plot(np.arange(len(train_losses)), train_losses, label='Training Loss')
  plt.plot(np.arange(len(val_losses)), val_losses, label='Validation Loss')
  plt.title('Training/Validation Loss for {} on {} across Epochs'.format(net_type, dataset))
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  
def plot_acc():
  fig = plt.figure(figsize=(15,6))
  plt.plot(np.arange(len(train_accs)), train_accs, label='Training Accuracy')
  plt.plot(np.arange(len(val_accs)), val_accs, label='Validation Accuracy')
  plt.title('Training/Validation Accuracy for {} on {} across Epochs'.format(net_type, dataset))
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  
plot_loss()
#plot_acc()

# %%
#net.unfreeze()
start_epoch=20
n_epochs=10
#lr=1e-6
(saved_epochs, train_losses, val_losses) = run()
# Out:
# => Training Epoch #20, LR=0.0010
# | Epoch [ 20/  9] Iter[932/933]		Iter Loss: 0.5691, Cumulative Loss: 243253.399872431
# | Validation Epoch #20
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.9158|    1.0836|                 1.0805|                 0.0025|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 20 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-20.pt
# | Saving Best model...			Loss = 225865.45
# | Elapsed time : 0:01:34
#
# => Training Epoch #21, LR=0.0010
# | Epoch [ 21/  9] Iter[932/933]		Iter Loss: 1.3859, Cumulative Loss: 225917.675128333
# | Validation Epoch #21
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.6123|    0.7309|                 0.7290|                 0.0022|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 21 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-21.pt
# | Saving Best model...			Loss = 210143.09
# | Elapsed time : 0:03:09
#
# => Training Epoch #22, LR=0.0010
# | Epoch [ 22/  9] Iter[932/933]		Iter Loss: 1.4551, Cumulative Loss: 209873.271279738
# | Validation Epoch #22
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.8296|    1.0482|                 1.0456|                 0.0023|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 22 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-22.pt
# | Saving Best model...			Loss = 194395.55
# | Elapsed time : 0:04:44
#
# => Training Epoch #23, LR=0.0010
# | Epoch [ 23/  9] Iter[932/933]		Iter Loss: 1.0150, Cumulative Loss: 194537.25077469
# | Validation Epoch #23
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.3599|    0.9747|                 0.9708|                 0.0020|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 23 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-23.pt
# | Saving Best model...			Loss = 179811.05
# | Elapsed time : 0:06:18
#
# => Training Epoch #24, LR=0.0010
# | Epoch [ 24/  9] Iter[932/933]		Iter Loss: 0.0392, Cumulative Loss: 179476.82368272
# | Validation Epoch #24
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.7992|    0.9098|                 0.9081|                 0.0022|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 24 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-24.pt
# | Saving Best model...			Loss = 165887.70
# | Elapsed time : 0:07:53
#
# => Training Epoch #25, LR=0.0010
# | Epoch [ 25/  9] Iter[932/933]		Iter Loss: 1.1054, Cumulative Loss: 166044.77125145
# | Validation Epoch #25
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.3661|    1.0422|                 1.0406|                 0.0022|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 25 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-25.pt
# | Saving Best model...			Loss = 152827.13
# | Elapsed time : 0:09:29
#
# => Training Epoch #26, LR=0.0010
# | Epoch [ 26/  9] Iter[932/933]		Iter Loss: 0.0585, Cumulative Loss: 152851.76612086
# | Validation Epoch #26
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.6865|    0.9250|                 0.9239|                 0.0020|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 26 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-26.pt
# | Saving Best model...			Loss = 140916.27
# | Elapsed time : 0:11:04
#
# => Training Epoch #27, LR=0.0010
# | Epoch [ 27/  9] Iter[932/933]		Iter Loss: 1.5284, Cumulative Loss: 141009.97248686
# | Validation Epoch #27
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.4697|    0.9842|                 0.9825|                 0.0021|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 27 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-27.pt
# | Saving Best model...			Loss = 129372.94
# | Elapsed time : 0:12:39
#
# => Training Epoch #28, LR=0.0010
# | Epoch [ 28/  9] Iter[932/933]		Iter Loss: 0.4945, Cumulative Loss: 129046.69937139
# | Validation Epoch #28
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -1.2374|    0.7430|                 0.7407|                 0.0021|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 28 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-28.pt
# | Saving Best model...			Loss = 117936.96
# | Elapsed time : 0:14:15
#
# => Training Epoch #29, LR=0.0010
# | Epoch [ 29/  9] Iter[932/933]		Iter Loss: 1.4956, Cumulative Loss: 118273.33942410
# | Validation Epoch #29
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.9570|    0.8475|                 0.8450|                 0.0019|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 29 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-29.pt
# | Saving Best model...			Loss = 107526.16
# | Elapsed time : 0:15:50
#
#  Test results : Loss = 107526.16

# %%
plot_loss()

# %%
#net.unfreeze()
start_epoch=30
n_epochs=10
#lr=1e-6
(saved_epochs, train_losses, val_losses) = run()
# Out:
# => Training Epoch #30, LR=0.0010
# | Epoch [ 30/  9] Iter[932/933]		Iter Loss: 0.2337, Cumulative Loss: 107557.6116621
# | Validation Epoch #30
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.7606|    0.8144|                 0.8125|                 0.0016|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 30 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-30.pt
# | Saving Best model...			Loss = 97785.00
# | Elapsed time : 0:01:35
#
# => Training Epoch #31, LR=0.0010
# | Epoch [ 31/  9] Iter[932/933]		Iter Loss: 1.3429, Cumulative Loss: 98458.96518944
# | Validation Epoch #31
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -1.1471|    0.7954|                 0.7937|                 0.0019|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 31 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-31.pt
# | Saving Best model...			Loss = 88707.72
# | Elapsed time : 0:03:10
#
# => Training Epoch #32, LR=0.0010
# | Epoch [ 32/  9] Iter[932/933]		Iter Loss: 0.3633, Cumulative Loss: 89342.97182632
# | Validation Epoch #32
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.8430|    1.1966|                 1.1948|                 0.0025|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 32 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-32.pt
# | Saving Best model...			Loss = 79844.93
# | Elapsed time : 0:04:45
#
# => Training Epoch #33, LR=0.0010
# | Epoch [ 33/  9] Iter[932/933]		Iter Loss: 0.5377, Cumulative Loss: 80857.23683517
# | Validation Epoch #33
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.8672|    1.1955|                 1.1931|                 0.0025|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 33 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-33.pt
# | Saving Best model...			Loss = 72359.58
# | Elapsed time : 0:06:21
#
# => Training Epoch #34, LR=0.0010
# | Epoch [ 34/  9] Iter[932/933]		Iter Loss: 0.9453, Cumulative Loss: 72557.06071065
# | Validation Epoch #34
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.6953|    1.0652|                 1.0636|                 0.0021|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 34 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-34.pt
# | Saving Best model...			Loss = 64506.44
# | Elapsed time : 0:07:56
#
# => Training Epoch #35, LR=0.0010
# | Epoch [ 35/  9] Iter[932/933]		Iter Loss: 0.2444, Cumulative Loss: 65052.50482798
# | Validation Epoch #35
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.7864|    0.9674|                 0.9662|                 0.0020|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 35 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-35.pt
# | Saving Best model...			Loss = 57729.58
# | Elapsed time : 0:09:32
#
# => Training Epoch #36, LR=0.0010
# | Epoch [ 36/  9] Iter[932/933]		Iter Loss: 1.1165, Cumulative Loss: 58286.10308875
# | Validation Epoch #36
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.2984|    0.8066|                 0.8047|                 0.0014|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 36 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-36.pt
# | Saving Best model...			Loss = 51199.23
# | Elapsed time : 0:11:07
#
# => Training Epoch #37, LR=0.0010
# | Epoch [ 37/  9] Iter[932/933]		Iter Loss: 0.5429, Cumulative Loss: 51503.17810944
# | Validation Epoch #37
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.5918|    0.8100|                 0.8084|                 0.0014|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 37 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-37.pt
# | Saving Best model...			Loss = 45469.87
# | Elapsed time : 0:12:42
#
# => Training Epoch #38, LR=0.0010
# | Epoch [ 38/  9] Iter[932/933]		Iter Loss: 0.8948, Cumulative Loss: 45761.98727534
# | Validation Epoch #38
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.9788|    0.9572|                 0.9563|                 0.0017|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 38 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-38.pt
# | Saving Best model...			Loss = 39721.76
# | Elapsed time : 0:14:17
#
# => Training Epoch #39, LR=0.0010
# | Epoch [ 39/  9] Iter[932/933]		Iter Loss: 1.3840, Cumulative Loss: 40332.03040698
# | Validation Epoch #39
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.9735|    0.9998|                 0.9986|                 0.0016|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 39 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-39.pt
# | Saving Best model...			Loss = 34519.12
# | Elapsed time : 0:15:53
#
#  Test results : Loss = 34519.12

# %%
plot_loss()

# %%
#net.unfreeze()
start_epoch=40
n_epochs=10
#lr=1e-6
(saved_epochs, train_losses, val_losses) = run()
# Out:
# => Training Epoch #40, LR=0.0010
# | Epoch [ 40/  9] Iter[932/933]		Iter Loss: 0.2122, Cumulative Loss: 35037.96197462
# | Validation Epoch #40
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.5460|    0.9389|                 0.9371|                 0.0016|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 40 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-40.pt
# | Saving Best model...			Loss = 30188.32
# | Elapsed time : 0:01:34
#
# => Training Epoch #41, LR=0.0010
# | Epoch [ 41/  9] Iter[932/933]		Iter Loss: 0.8128, Cumulative Loss: 30624.16646693
# | Validation Epoch #41
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -1.1801|    1.0307|                 1.0285|                 0.0020|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 41 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-41.pt
# | Saving Best model...			Loss = 25765.18
# | Elapsed time : 0:03:09
#
# => Training Epoch #42, LR=0.0010
# | Epoch [ 42/  9] Iter[932/933]		Iter Loss: 1.0224, Cumulative Loss: 26402.72613773
# | Validation Epoch #42
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.7110|    1.1569|                 1.1545|                 0.0021|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 42 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-42.pt
# | Saving Best model...			Loss = 22033.21
# | Elapsed time : 0:04:45
#
# => Training Epoch #43, LR=0.0010
# | Epoch [ 43/  9] Iter[932/933]		Iter Loss: 0.6168, Cumulative Loss: 22480.78650063
# | Validation Epoch #43
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -1.1700|    1.2025|                 1.2001|                 0.0023|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 43 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-43.pt
# | Saving Best model...			Loss = 18638.44
# | Elapsed time : 0:06:20
#
# => Training Epoch #44, LR=0.0010
# | Epoch [ 44/  9] Iter[932/933]		Iter Loss: 0.5075, Cumulative Loss: 19239.6307551
# | Validation Epoch #44
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.5719|    1.6322|                 1.6276|                 0.0027|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 44 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-44.pt
# | Saving Best model...			Loss = 15606.19
# | Elapsed time : 0:07:55
#
# => Training Epoch #45, LR=0.0010
# | Epoch [ 45/  9] Iter[932/933]		Iter Loss: 0.6714, Cumulative Loss: 16278.3716935
# | Validation Epoch #45
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.6304|    1.5473|                 1.5459|                 0.0025|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 45 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-45.pt
# | Saving Best model...			Loss = 13248.48
# | Elapsed time : 0:09:30
#
# => Training Epoch #46, LR=0.0010
# | Epoch [ 46/  9] Iter[932/933]		Iter Loss: 0.3822, Cumulative Loss: 13842.6224911
# | Validation Epoch #46
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.8346|    0.9149|                 0.9131|                 0.0018|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 46 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-46.pt
# | Saving Best model...			Loss = 11015.11
# | Elapsed time : 0:11:05
#
# => Training Epoch #47, LR=0.0010
# | Epoch [ 47/  9] Iter[932/933]		Iter Loss: 0.9153, Cumulative Loss: 11569.386137
# | Validation Epoch #47
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.8210|    0.8939|                 0.8924|                 0.0016|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 47 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-47.pt
# | Saving Best model...			Loss = 9221.54
# | Elapsed time : 0:12:39
#
# => Training Epoch #48, LR=0.0010
# | Epoch [ 48/  9] Iter[932/933]		Iter Loss: 0.7738, Cumulative Loss: 9724.9012092
# | Validation Epoch #48
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.6464|    0.8988|                 0.8976|                 0.0015|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 48 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-48.pt
# | Saving Best model...			Loss = 7856.01
# | Elapsed time : 0:14:14
#
# => Training Epoch #49, LR=0.0010
# | Epoch [ 49/  9] Iter[932/933]		Iter Loss: 0.6707, Cumulative Loss: 8422.8666211
# | Validation Epoch #49
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.8893|    1.0552|                 1.0530|                 0.0018|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 49 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-49.pt
# | Saving Best model...			Loss = 6753.19
# | Elapsed time : 0:15:49
#
#  Test results : Loss = 6753.19

# %%
plot_loss()

# %%
#net.unfreeze()
start_epoch=50
n_epochs=10
#lr=1e-6
(saved_epochs, train_losses, val_losses) = run()
# Out:
# => Training Epoch #50, LR=0.0010
# | Epoch [ 50/  9] Iter[932/933]		Iter Loss: 1.0443, Cumulative Loss: 7203.1613169
# | Validation Epoch #50
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.7196|    0.9198|                 0.9177|                 0.0016|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 50 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-50.pt
# | Saving Best model...			Loss = 5846.44
# | Elapsed time : 0:01:34
#
# => Training Epoch #51, LR=0.0010
# | Epoch [ 51/  9] Iter[932/933]		Iter Loss: 0.6907, Cumulative Loss: 6568.3208016
# | Validation Epoch #51
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -1.0025|    1.1018|                 1.1003|                 0.0019|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 51 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-51.pt
# | Saving Best model...			Loss = 5461.67
# | Elapsed time : 0:03:09
#
# => Training Epoch #52, LR=0.0010
# | Epoch [ 52/  9] Iter[932/933]		Iter Loss: 0.7253, Cumulative Loss: 6125.8639302
# | Validation Epoch #52
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.5849|    0.9081|                 0.9069|                 0.0014|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 52 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-52.pt
# | Saving Best model...			Loss = 5254.23
# | Elapsed time : 0:04:44
#
# => Training Epoch #53, LR=0.0010
# | Epoch [ 53/  9] Iter[932/933]		Iter Loss: 1.2764, Cumulative Loss: 5833.6843978
# | Validation Epoch #53
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.6091|    0.7537|                 0.7530|                 0.0014|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 53 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-53.pt
# | Elapsed time : 0:06:18
#
# => Training Epoch #54, LR=0.0010
# | Epoch [ 54/  9] Iter[932/933]		Iter Loss: 0.6030, Cumulative Loss: 6002.4148333
# | Validation Epoch #54
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.7061|    0.9117|                 0.9105|                 0.0014|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 54 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-54.pt
# | Elapsed time : 0:07:53
#
# => Training Epoch #55, LR=0.0010
# | Epoch [ 55/  9] Iter[932/933]		Iter Loss: 0.2999, Cumulative Loss: 6319.6114743
# | Validation Epoch #55
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.7161|    0.8758|                 0.8742|                 0.0014|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 55 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-55.pt
# | Elapsed time : 0:09:27
#
# => Training Epoch #56, LR=0.0010
# | Epoch [ 56/  9] Iter[932/933]		Iter Loss: 1.2596, Cumulative Loss: 7033.9007814
# | Validation Epoch #56
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -1.1464|    1.1331|                 1.1310|                 0.0019|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 56 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-56.pt
# | Elapsed time : 0:11:02
#
# => Training Epoch #57, LR=0.0010
# | Epoch [ 57/  9] Iter[932/933]		Iter Loss: 1.2370, Cumulative Loss: 7858.8247093
# | Validation Epoch #57
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.4950|    1.0022|                 1.0006|                 0.0015|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 57 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-57.pt
# | Elapsed time : 0:12:36
#
# => Training Epoch #58, LR=0.0010
# | Epoch [ 58/  9] Iter[932/933]		Iter Loss: 0.5537, Cumulative Loss: 8997.6913088
# | Validation Epoch #58
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.1752|    0.9017|                 0.9004|                 0.0014|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 58 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-58.pt
# | Elapsed time : 0:14:11
#
# => Training Epoch #59, LR=0.0010
# | Epoch [ 59/  9] Iter[932/933]		Iter Loss: 1.0239, Cumulative Loss: 10290.172629
# | Validation Epoch #59
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -1.0150|    0.9643|                 0.9621|                 0.0016|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 59 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-59.pt
# | Elapsed time : 0:15:46
#
#  Test results : Loss = 5254.23

# %%
plot_loss()

# %%
def load_states():
  states = []
  for epoch in range(60): #saved_epochs:
    filename = './checkpoint/checkpoint-{}-{}-epoch-{}.pt'.format(net_type, dataset, epoch)
    state = torch.load(filename)
    states.append(state)
  return states

states = load_states()

# %%
#idx_interest = [0, 10, 20, 50, 100, 200, 500, 999]
nets = [state['net'] for idx, state in enumerate(states) ]#if idx in idx_interest] #%1 == 0]# 
epochs = [state['epoch'] for idx, state in enumerate(states) ]#if idx in idx_interest] #%1 == 0]#

# %%
net = nets[52]

# %%
net.unfreeze()
start_epoch=53
n_epochs=15
lr=1e-6
(saved_epochs, train_losses, val_losses) = run()
# Out:
# => Training Epoch #53, LR=0.0000
# | Epoch [ 53/ 14] Iter[932/933]		Iter Loss: 0.5877, Cumulative Loss: 5900.2562233
# | Validation Epoch #53
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.7480|    1.0949|                 1.0928|                 0.0014|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 53 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-53.pt
# | Saving Best model...			Loss = 5157.89
# /opt/anaconda3/lib/python3.7/site-packages/torch/serialization.py:256: UserWarning: Couldn't retrieve source code for container of type BayesianPreTrainedModel. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# | Elapsed time : 0:03:53
#
# => Training Epoch #54, LR=0.0000
# | Epoch [ 54/ 14] Iter[932/933]		Iter Loss: 1.0754, Cumulative Loss: 5834.8402725
# | Validation Epoch #54
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.6623|    1.2734|                 1.2712|                 0.0014|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 54 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-54.pt
# | Elapsed time : 0:07:44
#
# => Training Epoch #55, LR=0.0000
# | Epoch [ 55/ 14] Iter[932/933]		Iter Loss: 1.0828, Cumulative Loss: 5674.3602511
# | Validation Epoch #55
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.8323|    1.3693|                 1.3675|                 0.0014|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 55 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-55.pt
# | Elapsed time : 0:11:34
#
# => Training Epoch #56, LR=0.0000
# | Epoch [ 56/ 14] Iter[932/933]		Iter Loss: 0.7545, Cumulative Loss: 5763.0645742
# | Validation Epoch #56
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.7163|    1.4422|                 1.4425|                 0.0014|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 56 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-56.pt
# | Saving Best model...			Loss = 5154.63
# | Elapsed time : 0:15:24
#
# => Training Epoch #57, LR=0.0000
# | Epoch [ 57/ 14] Iter[932/933]		Iter Loss: 0.8831, Cumulative Loss: 5646.7601038
# | Validation Epoch #57
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.7850|    1.5781|                 1.5769|                 0.0015|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 57 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-57.pt
# | Saving Best model...			Loss = 5085.69
# | Elapsed time : 0:19:13
#
# => Training Epoch #58, LR=0.0000
# | Epoch [ 58/ 14] Iter[932/933]		Iter Loss: 1.4174, Cumulative Loss: 5620.9559602
# | Validation Epoch #58
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.6638|    1.6649|                 1.6639|                 0.0014|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 58 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-58.pt
# | Elapsed time : 0:23:02
#
# => Training Epoch #59, LR=0.0000
# | Epoch [ 59/ 14] Iter[932/933]		Iter Loss: 0.9212, Cumulative Loss: 5534.0037808
# | Validation Epoch #59
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.7194|    1.5914|                 1.5897|                 0.0014|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 59 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-59.pt
# | Elapsed time : 0:26:51
#
# => Training Epoch #60, LR=0.0000
# | Epoch [ 60/ 14] Iter[932/933]		Iter Loss: 0.3362, Cumulative Loss: 5622.0151224
# | Validation Epoch #60
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.6506|    1.7268|                 1.7268|                 0.0014|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 60 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-60.pt
# | Elapsed time : 0:30:41
#
# => Training Epoch #61, LR=0.0000
# | Epoch [ 61/ 14] Iter[932/933]		Iter Loss: 0.3239, Cumulative Loss: 5619.5462009
# | Validation Epoch #61
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.5552|    1.7516|                 1.7512|                 0.0014|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 61 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-61.pt
# | Elapsed time : 0:34:31
#
# => Training Epoch #62, LR=0.0000
# | Epoch [ 62/ 14] Iter[932/933]		Iter Loss: 0.5376, Cumulative Loss: 5661.3045798
# | Validation Epoch #62
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.7938|    1.7483|                 1.7473|                 0.0014|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 62 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-62.pt
# | Elapsed time : 0:38:20
#
# => Training Epoch #63, LR=0.0000
# | Epoch [ 63/ 14] Iter[932/933]		Iter Loss: 0.7671, Cumulative Loss: 5482.6059218
# | Validation Epoch #63
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.6263|    1.7580|                 1.7561|                 0.0014|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 63 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-63.pt
# | Elapsed time : 0:42:09
#
# => Training Epoch #64, LR=0.0000
# | Epoch [ 64/ 14] Iter[932/933]		Iter Loss: 1.0865, Cumulative Loss: 5560.8757191
# | Validation Epoch #64
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.5783|    1.7535|                 1.7521|                 0.0013|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 64 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-64.pt
# | Elapsed time : 0:45:57
#
# => Training Epoch #65, LR=0.0000
# | Epoch [ 65/ 14] Iter[932/933]		Iter Loss: 0.9829, Cumulative Loss: 5542.9944629
# | Validation Epoch #65
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.6038|    1.7973|                 1.7962|                 0.0014|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 65 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-65.pt
# | Elapsed time : 0:49:46
#
# => Training Epoch #66, LR=0.0000
# | Epoch [ 66/ 14] Iter[932/933]		Iter Loss: -0.0024, Cumulative Loss: 5604.291611
# | Validation Epoch #66
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.7549|    1.7891|                 1.7890|                 0.0015|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 66 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-66.pt
# | Elapsed time : 0:53:35
#
# => Training Epoch #67, LR=0.0000
# | Epoch [ 67/ 14] Iter[932/933]		Iter Loss: 0.4070, Cumulative Loss: 5736.0202601
# | Validation Epoch #67
#
#
# ----------------------------------------------------------------------------------------------
#
# |      Parameter| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |  Einstein Area|          -0.6912|    1.7124|                 1.7123|                 0.0014|
#
# ----------------------------------------------------------------------------------------------
#
#
# Saved Epoch 67 as ./checkpoint/checkpoint-alexnet-stronglens-challenge-epoch-67.pt
# | Elapsed time : 0:57:24
#
#  Test results : Loss = 5085.69

# %%
plot_loss()

# %%
net
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d3e61c39d23b> in <module>
# ----> 1 net
#
# NameError: name 'net' is not defined

# %% [markdown]
# Helper functions to get predictions on a dataset, and do a scatterplot of true vs predicted values.

# %%
def load_states():
  states = []
  for epoch in range(68): #saved_epochs:
    filename = './checkpoint/checkpoint-{}-{}-epoch-{}.pt'.format(net_type, dataset, epoch)
    state = torch.load(filename)
    states.append(state)
  return states

states = load_states()

# %%
#idx_interest = [0, 10, 20, 50, 100, 200, 500, 999]
nets = [state['net'] for idx, state in enumerate(states) ]#if idx in idx_interest] #%1 == 0]# 
epochs = [state['epoch'] for idx, state in enumerate(states) ]#if idx in idx_interest] #%1 == 0]#

# %%
target_sum = 0.0
target_count = 0
for _, targets in trainloader:
    #print(targets.shape)
    target_sum += targets.detach().cpu().numpy().squeeze().sum()
    target_count += targets.shape[0]
train_mean = target_sum/target_count

# %%
labs = []
shape = 0
for _, targets in testloader:
    shape += targets.shape[0]
    #print(shape)
    labs.extend(targets.detach().cpu().numpy().squeeze())
print(len(labs))
labs = np.array(labs).squeeze()
print(labs.shape)
# Out:
# 3730
# (3730,)

# %%
def get_predictions(dataloader, epoch=None):
    predsMean = []
    predsVar = []
    for batch_idx, (inputs_value, targets) in enumerate(dataloader):
        x = inputs_value.view(-1, inputs, resize, resize).repeat(num_samples, 1, 1, 1)
        #x_nobias = remove_image_intensity_bias(x)
        #x = x_nobias.repeat(num_samples, 1, 1, 1)
        y = targets.view(-1, outputs).repeat(num_samples, 1)
        if use_cuda:
            x, y = x.cuda(), y.cuda()
        with torch.no_grad():
            x, y = Variable(x), Variable(y)
        modl = net if epoch is None else nets[epoch]    
        outs, kl = modl.probforward(x)
        preds = outs.detach().cpu().numpy()
        #print(preds.shape)
        preds = preds.reshape(num_samples, -1, outputs)
        mean_preds = preds.mean(axis=0)
        var_preds = preds.var(axis=0)
        #print(mean_preds)
        predsMean.extend(mean_preds.squeeze())
        predsVar.extend(var_preds.squeeze())
    return (np.array(predsMean), np.array(predsVar))

# %%
preds = get_predictions(testloader, epoch=9)

# %%
def scatter_plots(epoch=None):
    preds, predsVar = get_predictions(testloader, epoch=epoch)
    print(predsVar)
    #print(preds.shape)
    #print(testY.shape)
    #print(preds)
    #print(testY)
    fig, ax = plt.subplots(figsize=(15,6))
    points = [[-4, 4]]
    trainY_mean = train_mean
    #print(labs.shape)
    #print(preds.shape)
    lr = LinearRegression()
    lr.fit(labs.reshape(-1, 1), preds)
    pp = lr.predict(labs.reshape(-1, 1))  
    for j in range(outputs):
        #ax.errorbar(labs.squeeze(), preds, yerr=predsVar, fmt='o', ecolor='r')
        sns.scatterplot(x=labs.squeeze(), y=preds, ax=ax)
        ax.plot(points[j], points[j], '--r', label='ideal relationship line')
        ax.plot(points[j], [trainY_mean, trainY_mean], '--g', label='line if predicting train mean')
        ax.plot(labs, pp, '--b', label='current relationship line')
        ax.set_xlabel('{}: true'.format(output_names[j]))
        ax.set_ylabel('{}: predicted'.format(output_names[j]))
        ax.set_xlim(points[j])
        ax.set_ylim(points[j])
        ax.legend()
    fig.suptitle('Scatter plots for true vs predicted values for the parameters')
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# %%
scatter_plots()
# Out:
# [0.000734 0.001453 0.000788 0.002106 ... 0.001925 0.000738 0.000908 0.003684]

# %%
scatter_plots(epoch=56)
# Out:
# [0.000438 0.000731 0.001923 0.002076 ... 0.001166 0.002893 0.002037 0.003031]

# %%
scatter_plots(epoch=52)
# Out:
# [0.000476 0.001702 0.001013 0.001832 ... 0.001404 0.002995 0.002726 0.001579]

# %%
def scatter_plots_error_bar(epoch=None):
    preds, predsVar = get_predictions(testloader, epoch=epoch)
    print(predsVar)
    #print(preds.shape)
    #print(testY.shape)
    #print(preds)
    #print(testY)
    fig, ax = plt.subplots(figsize=(15,36))
    points = [[-4, 4]]
    trainY_mean = train_mean
    #print(labs.shape)
    #print(preds.shape)
    lr = LinearRegression()
    lr.fit(labs.reshape(-1, 1), preds)
    pp = lr.predict(labs.reshape(-1, 1))  
    for j in range(outputs):
        ax.errorbar(labs.squeeze(), preds, yerr=predsVar, fmt='o', ecolor='r')
        #sns.scatterplot(x=labs.squeeze(), y=preds, ax=ax)
        ax.plot(points[j], points[j], '--r', label='ideal relationship line')
        ax.plot(points[j], [trainY_mean, trainY_mean], '--g', label='line if predicting train mean')
        ax.plot(labs, pp, '--b', label='current relationship line')
        ax.set_xlabel('{}: true'.format(output_names[j]))
        ax.set_ylabel('{}: predicted'.format(output_names[j]))
        ax.set_xlim(points[j])
        ax.set_ylim(points[j])
        ax.legend()
    fig.suptitle('Scatter plots for true vs predicted values for the parameters')
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# %%
scatter_plots_error_bar()
# Out:
# [0.001338 0.000956 0.001009 0.001484 ... 0.002586 0.001901 0.001152 0.005054]

# %% [markdown]
# Get predictions for a single feature by running it multiple times through a  given model. Plot the resulting histogram, which will be an approximation of the predictive distribution.

# %%
def sample_predictive_epoch(feat, idx, n_iter=100000):
  batch_size = n_iter
  shape = feat.shape
  x = feat.view(-1, inputs, resize, resize)
  #x_nobias = remove_image_intensity_bias(x)
  feat_rep = x.repeat(batch_size, 1, 1, 1)
  if use_cuda:
        feat_rep = feat_rep.cuda()
  outs, kl, means, stds = nets[idx].probforward(feat_rep, ret_mean_std=True)
  outputs = outs.detach().cpu().numpy()
  #outputs = normalize(softplus(outs.detach().cpu().numpy()), axis=1, norm='l1')
  mn = means.detach().cpu().numpy()
  vn = (stds.detach().cpu().numpy() ** 2)
  confidence_mean = np.mean(outputs, axis=0)
  confidence_var = np.var(outputs, axis=0)
  epistemic = np.mean(mn ** 2, axis=0) - np.mean(mn, axis=0) ** 2 #np.mean(p_hat ** 2, axis=0) - np.mean(p_hat, axis=0) ** 2
  aleatoric = np.mean(vn, axis=0)
  
  return outputs, confidence_mean, confidence_var, epistemic, aleatoric

# %%
def plot_epochs(feat, label, epochs, n_iter=1000):
    output_names=['Log Einstein Area']
    n_epochs = len(epochs)
    #print(epochs)
    label = label.reshape(-1, outputs)
    meanY = np.array([train_mean]).reshape(-1, outputs)
    fig, ax = plt.subplots(nrows = n_epochs + 4, ncols = 2, figsize=(15, 5*n_epochs))
    means = np.zeros((outputs, n_epochs))
    vars = np.zeros((outputs, n_epochs))
    epistemics = np.zeros((outputs, n_epochs))
    aleatorics = np.zeros((outputs, n_epochs))
    bins = [np.linspace(-4, 4, 100)]
    xlims = [[-4.5, 4.5]]
    for i, epoch in enumerate(epochs):
        preds, m, v, ep, al = sample_predictive_epoch(feat, epoch, n_iter)
        means[:, i] = m
        vars[:, i] = v
        epistemics[:, i] = ep
        aleatorics[:, i] = al
        for j in range(outputs):
            lab = label[j][0]
            #print(lab)
            #print(preds.shape)
            sns.distplot(preds[:, j], ax=ax[i, j], kde=False, bins=bins[j], label='Epoch {}'.format(epoch))
            ax[i, j].plot([lab, lab], [0, 1000], 'r-', linewidth=2, label='Target = {:.4f}'.format(lab))
            ax[i, j].plot([meanY[j][0], meanY[j][0]], [0, 1000], 'g-', linewidth=2, label='Mean(trainY) = {:.4f}'.format(meanY[j][0]))
            ax[i, j].set_xlabel(output_names[j])
            ax[i, j].set_ylabel('hist count')
            ax[i, j].set_xlim(xlims[j])
            ax[i, j].set_xticks(np.arange(xlims[j][0], xlims[j][1], 0.75))
            ax[i, j].set_ylim(0, 100)
            ax[i, j].legend()
    
    estimates = [means, vars, epistemics, aleatorics]
    estimate_names = ['confidence_mean', 'confidence_var', 'epistemic uncertainty', 'aleatoric uncertainty']
    for i in range(n_epochs, n_epochs + 4):
        for j in range(outputs):
            idx = i - n_epochs
            sns.lineplot(x = epochs, y  = estimates[idx][j, :], ax=ax[i, j])
            ax[i, j].set_xlabel('#Epochs ({})'.format(output_names[j]))
            ax[i, j].set_ylabel(estimate_names[idx])
            ax[i, j].set_xticks(np.linspace(epochs[0], epochs[-1], 4))
    fig.suptitle('Sampled Predictive Distribution and estimates across Epochs.')
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()
    
    print('\n\nParameter Estiamtes with Uncertainties:\n\n')
    epochs_str = [str(ep) for ep in epochs]
    for j in range(outputs):
        print('Parameter: {}'.format(output_names[j]))
        pp_estimates(epochs_str, means[j, :], vars[j, :], epistemics[j, :], aleatorics[j, :], tag='Epoch #' )

# %%
dataloader = iter(testloader)

# %%
features, labels = next(dataloader)

# %%
labels = labels.cpu().numpy()

# %%
plot_epochs(features[5], labels[5], epochs[::5], n_iter=1000)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-34-b9be0dd6a391> in <module>
# ----> 1 plot_epochs(features[5], labels[5], epochs[::5], n_iter=1000)
#
# <ipython-input-30-1a30540c4dd1> in plot_epochs(feat, label, epochs, n_iter)
#      13     xlims = [[-4.5, 4.5]]
#      14     for i, epoch in enumerate(epochs):
# ---> 15         preds, m, v, ep, al = sample_predictive_epoch(feat, epoch, n_iter)
#      16         means[:, i] = m
#      17         vars[:, i] = v
#
# <ipython-input-29-91acb13a8d52> in sample_predictive_epoch(feat, idx, n_iter)
#       7   if use_cuda:
#       8         feat_rep = feat_rep.cuda()
# ----> 9   outs, kl, means, stds = nets[idx].probforward(feat_rep, ret_mean_std=True)
#      10   outputs = outs.detach().cpu().numpy()
#      11   #outputs = normalize(softplus(outs.detach().cpu().numpy()), axis=1, norm='l1')
#
# <ipython-input-18-ff1659d55054> in probforward(self, x, ret_mean_std)
#      47                 kl += _kl
#      48         else:
# ---> 49             x = layer(x)
#      50     logits = x
#      51     #print('logits', logits)
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# /opt/anaconda3/lib/python3.7/site-packages/torchvision/models/resnet.py in forward(self, x)
#      57         identity = x
#      58
# ---> 59         out = self.conv1(x)
#      60         out = self.bn1(out)
#      61         out = self.relu(out)
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     341
#     342     def forward(self, input):
# --> 343         return self.conv2d_forward(input, self.weight)
#     344
#     345 class Conv3d(_ConvNd):
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py in conv2d_forward(self, input, weight)
#     338                             _pair(0), self.dilation, self.groups)
#     339         return F.conv2d(input, weight, self.bias, self.stride,
# --> 340                         self.padding, self.dilation, self.groups)
#     341
#     342     def forward(self, input):
#
# RuntimeError: CUDA out of memory. Tried to allocate 766.00 MiB (GPU 0; 15.90 GiB total capacity; 14.74 GiB already allocated; 179.88 MiB free; 338.46 MiB cached)

# %%
plot_epochs(features[10], labels[10], epochs, n_iter=1000)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-50-4f9fc29934cd> in <module>
# ----> 1 plot_epochs(features[10], labels[10], epochs, n_iter=1000)
#
# <ipython-input-45-1a30540c4dd1> in plot_epochs(feat, label, epochs, n_iter)
#      13     xlims = [[-4.5, 4.5]]
#      14     for i, epoch in enumerate(epochs):
# ---> 15         preds, m, v, ep, al = sample_predictive_epoch(feat, epoch, n_iter)
#      16         means[:, i] = m
#      17         vars[:, i] = v
#
# <ipython-input-44-91acb13a8d52> in sample_predictive_epoch(feat, idx, n_iter)
#       7   if use_cuda:
#       8         feat_rep = feat_rep.cuda()
# ----> 9   outs, kl, means, stds = nets[idx].probforward(feat_rep, ret_mean_std=True)
#      10   outputs = outs.detach().cpu().numpy()
#      11   #outputs = normalize(softplus(outs.detach().cpu().numpy()), axis=1, norm='l1')
#
# <ipython-input-18-ff1659d55054> in probforward(self, x, ret_mean_std)
#      47                 kl += _kl
#      48         else:
# ---> 49             x = layer(x)
#      50     logits = x
#      51     #print('logits', logits)
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# /opt/anaconda3/lib/python3.7/site-packages/torchvision/models/resnet.py in forward(self, x)
#      61         out = self.relu(out)
#      62
# ---> 63         out = self.conv2(out)
#      64         out = self.bn2(out)
#      65
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     341
#     342     def forward(self, input):
# --> 343         return self.conv2d_forward(input, self.weight)
#     344
#     345 class Conv3d(_ConvNd):
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py in conv2d_forward(self, input, weight)
#     338                             _pair(0), self.dilation, self.groups)
#     339         return F.conv2d(input, weight, self.bias, self.stride,
# --> 340                         self.padding, self.dilation, self.groups)
#     341
#     342     def forward(self, input):
#
# RuntimeError: CUDA out of memory. Tried to allocate 766.00 MiB (GPU 0; 15.90 GiB total capacity; 13.91 GiB already allocated; 281.88 MiB free; 1.05 GiB cached)

# %%
plot_epochs(features[15], labels[15], epochs, n_iter=1000)
# Out:
# Parameter Estiamtes with Uncertainties:
#
#
# Parameter: Log Einstein Area
#
#
# ----------------------------------------------------------------------------------------------
#
# |        Epoch #| Confidence Mean | Variance | Epistemic Uncertainty | Aleatoric Uncertainty |
#
# ----------------------------------------------------------------------------------------------
#
# |              0|          -2.1651|    0.1559|                 0.0908|                 0.0545|
#
# |              1|          -2.4119|    0.0697|                 0.0500|                 0.0236|
#
# |              2|          -1.9289|    0.0483|                 0.0377|                 0.0120|
#
# |              3|          -2.4366|    0.0481|                 0.0384|                 0.0075|
#
# |              4|          -2.4516|    0.0248|                 0.0215|                 0.0045|
#
# |              5|          -2.3685|    0.0376|                 0.0342|                 0.0037|
#
# |              6|          -2.0253|    0.0281|                 0.0243|                 0.0025|
#
# |              7|          -2.4203|    0.0285|                 0.0250|                 0.0032|
#
# |              8|          -2.7958|    0.0238|                 0.0195|                 0.0033|
#
# |              9|          -2.9537|    0.0280|                 0.0251|                 0.0030|
#
# |             10|          -2.4381|    0.0167|                 0.0153|                 0.0018|
#
# |             11|          -2.7933|    0.0173|                 0.0144|                 0.0024|
#
# |             12|          -2.6654|    0.0089|                 0.0064|                 0.0024|
#
# |             13|          -2.6959|    0.0153|                 0.0128|                 0.0023|
#
# |             14|          -2.6015|    0.0114|                 0.0093|                 0.0021|
#
# |             15|          -2.5583|    0.0082|                 0.0059|                 0.0022|
#
# |             16|          -2.5381|    0.0102|                 0.0077|                 0.0024|
#
# |             17|          -2.4838|    0.0060|                 0.0035|                 0.0028|
#
# |             18|          -2.8519|    0.0082|                 0.0039|                 0.0043|
#
# |             19|          -2.8825|    0.0093|                 0.0060|                 0.0036|
#
# |             20|          -3.6440|    0.0149|                 0.0085|                 0.0066|
#
# |             21|          -2.7180|    0.0052|                 0.0020|                 0.0032|
#
# |             22|          -2.4295|    0.0051|                 0.0027|                 0.0026|
#
# |             23|          -2.5289|    0.0037|                 0.0019|                 0.0022|
#
# |             24|          -2.3980|    0.0038|                 0.0017|                 0.0022|
#
# |             25|          -2.0843|    0.0027|                 0.0013|                 0.0014|
#
# |             26|          -2.5300|    0.0031|                 0.0006|                 0.0025|
#
# |             27|          -3.0479|    0.0037|                 0.0008|                 0.0030|
#
# |             28|          -2.8391|    0.0040|                 0.0009|                 0.0031|
#
# |             29|          -2.6169|    0.0040|                 0.0008|                 0.0030|
#
# |             30|          -2.8583|    0.0037|                 0.0007|                 0.0028|
#
# |             31|          -2.7024|    0.0030|                 0.0007|                 0.0025|
#
# |             32|          -2.9450|    0.0038|                 0.0006|                 0.0030|
#
# |             33|          -3.0832|    0.0050|                 0.0006|                 0.0043|
#
# |             34|          -2.3280|    0.0024|                 0.0006|                 0.0019|
#
# |             35|          -3.0070|    0.0048|                 0.0008|                 0.0041|
#
# |             36|          -2.5225|    0.0025|                 0.0006|                 0.0022|
#
# |             37|          -2.7497|    0.0046|                 0.0007|                 0.0038|
#
# |             38|          -2.6048|    0.0033|                 0.0007|                 0.0027|
#
# |             39|          -2.5621|    0.0030|                 0.0006|                 0.0022|
#
# |             40|          -2.5859|    0.0030|                 0.0006|                 0.0023|
#
# |             41|          -3.0328|    0.0047|                 0.0007|                 0.0043|
#
# |             42|          -2.0980|    0.0020|                 0.0005|                 0.0015|
#
# |             43|          -2.7276|    0.0026|                 0.0006|                 0.0022|
#
# |             44|          -3.1693|    0.0039|                 0.0007|                 0.0036|
#
# |             45|          -2.8401|    0.0031|                 0.0006|                 0.0026|
#
# |             46|          -2.6436|    0.0025|                 0.0006|                 0.0021|
#
# |             47|          -2.6529|    0.0026|                 0.0005|                 0.0020|
#
# |             48|          -2.7692|    0.0028|                 0.0005|                 0.0023|
#
# |             49|          -2.8707|    0.0030|                 0.0006|                 0.0025|
#
# ----------------------------------------------------------------------------------------------

# %%
start_epoch
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dd8efa11ec1e> in <module>
# ----> 1 start_epoch
#
# NameError: name 'start_epoch' is not defined

# %%
torch.cuda.empty_cache()
